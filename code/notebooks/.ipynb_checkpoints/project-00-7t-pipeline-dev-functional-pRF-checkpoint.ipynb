# %% [markdown]
# # Layer-specific fMRI processing pipeline: functional processing & pRF mapping
#
# It is assumed that this workflow is run following the laminar-fMRI-pipeline-advanced-skullstrip workflow.
#
# The functional processing pipeline aims to follow the steps followed in fMRIPrep, adapted for partial FoV fMRI data. Reasons for not using fMRIPrep directly:
# - from fMRIPrep website: a reason not to use fMRIPrep is very narrow FoV images, which often do not contain enough information for standard image registration methods to work correctly
# - fMRIPrep is designed to take a T1 MPRAGE image as input, not MP2RAGE
# - pRF mapping can be carried out in native space - here we avoid additional data perturbations by keeping the data in native space
#
# The pipeline uses the anatomical surface reconstruction from the laminar-fMRI-pipeline-advanced-skullstrip workflow as input. The steps implemented in the pipeline are as follows:
# - discard initial fMRI volumes to allow for T1 equilibration
# - realignment: head-motion estimation and correction (FSL MCFLIRT); within and between sessions
# - (optional) susceptibility-derived distortion estimation and unwarping (AFNI 3dqwarp)
# - (optional) slice-timing correction (AFNI 3dTshift)
# - compute temporal SNR (to assess the noisiness of the data in different brain areas)
# - co-registration of functional and structural data (FreeSurfer bbregister, FLIRT FSL) - note: structural data is brought into functional space to avoid superfluous interpolation of functional volumes!
# - iteratively: check results (and manual correction) w/ tkregisterfv and run bbregister again
# - surface sampling (FreeSurfer mri_vol2surf)
# - confounds (FSL fsl_motion_outliers then fsl_regfilt?)
# - detection of non-steady states ???
#
# pRF: decide on software
# - what format of input data?
# - what format of aperture parameters?
# - anatomical priors (neuropythy)
# - combine empirical estimate and anatomical priors for Bayesian
# - decide which sessions to use (pol, ecc, bar)
#
#
# try using raw image (not skull-stripped) for coreg

# %% [markdown]
# ### Set preferences
# Whether or not to write the workflow viz graph, run pipeline, run specific branches of workflow...

# %%
# whether or not to run the pipeline
run_pipeline = True   

# whether or not to write workflow graph (svg)
write_graph  = True                           
                        
# whether manual edits exist (for coregistration)
manual_edits = True      

# whether to do unwarping
unwarp = False         

# whether to do coregistration
coregister = True

# coregistration method: 'flirt','freesurfer', 'antsRegistration' or 'itk-snap'
coreg_method = 'antsRegistration' 

# coregistration direction: either from functional to structural ('func2struct') or vice versa ('struct2func')
coreg_dir = 'func2struct'

# number of cores to use: either set explicitly or based on settings in batch file
import os
#n_procs = 1
n_procs = int(os.getenv('OMP_NUM_THREADS'))   
print(n_procs)

# field map method (https://lcni.uoregon.edu/kb-articles/kb-0003)
# Method 1 calculates a field map based on the difference in phase 
# between two different echos in a double echo sequence. 
# Method 2 uses two separate acquisitions with opposite phase encoding 
# directions to calculate a field map based on the difference in 
# distortion between the two acquisitions.
fmap_method = 1
# Out:
# 1

# %% [markdown]
# ### Set paths
# All computer-dependent paths

# %%
from os.path import join as opj

doc_dir = '/home/mayaaj90/'
data_dir = '/scratch/mayaaj90/project-00-7t-pipeline-dev/'

# general software directory
software_dir = opj(doc_dir,'programs')

# SPM dir
spm_dir = opj(software_dir,'spm12')

# data directory
raw_data_dir = opj(data_dir,'raw')

# scripts directory
der_dir = opj(data_dir,'derivatives')

# dicoms directory
dicom_dir = opj(data_dir,'dicoms')

# location of freesurfer skull-stripped T1 (output of structural processing pipeline)
struct_out = opj(data_dir,'output','freesurfer_externalbrainmask')

# pRF directories
pRF_dir = opj(data_dir,'pRF')
pRF_FS_dir = opj(data_dir,'pRF','data_FS')

# output directory for datasink
out_dir = opj(data_dir,'output')

# FS output from anatomy pipeline
subjects_dir = opj(data_dir,'pRF','data_FS')
os.environ['SUBJECTS_DIR']=subjects_dir

# %%
os.environ['SUBJECTS_DIR']
# Out:
# '/scratch/mayaaj90/project-00-7t-pipeline-dev/pRF/data_FS'

# %% [markdown]
# ### Imports
# Import required libraries, set paths

# %%
import re

from nipype.interfaces.io import DataGrabber, DataSink

from nipype import Node, MapNode, JoinNode, Workflow

from nipype.interfaces.freesurfer import MRIConvert, SampleToSurface

#import nipype_settings
import nipype.interfaces.matlab as Matlab
from nipype.interfaces.base import (
    CommandLineInputSpec,
    CommandLine,
    TraitedSpec,
    BaseInterface, 
    BaseInterfaceInputSpec, 
    File,
    Directory
)

from string import Template

from nipype.interfaces.utility import Function, IdentityInterface, Merge, Select
from nipype.interfaces.base import BaseInterface, BaseInterfaceInputSpec, CommandLine, Directory, File, TraitedSpec, traits

from nipype import config
config.enable_debug_mode()

from os.path import abspath

from nipype.interfaces.freesurfer.model import Binarize

import pygraphviz 

from pydicom.data import get_testdata_file
from pydicom import dcmread

from nipype.interfaces.fsl import BET, PrepareFieldmap, ExtractROI, MCFLIRT, Merge, ConvertXFM, FLIRT

from nipype.interfaces.freesurfer.registration import MRICoreg
from nipype.interfaces.freesurfer.preprocess import BBRegister

from nipype.interfaces.dcmstack import MergeNifti

import sys
sys.path.append(software_dir)
from ApplyXfm4D import ApplyXfm4D

from nipype.interfaces.fsl.preprocess import FUGUE

from nipype.interfaces.afni import Warp, TShift

from nipype.interfaces.spm import SliceTiming

import neuropythy as ny

import nipype.interfaces.matlab as Matlab

from nipype.interfaces.ants.registration import Registration
from nipype.interfaces.ants import N4BiasFieldCorrection
from nipype.interfaces.ants import ApplyTransforms

from nipype.interfaces.fsl.maths import BinaryMaths

# set SPM path
os.environ['SPM_PATH']=spm_dir

from nipype.interfaces import spm
spm.SPMCommand.set_mlab_paths(paths=spm_dir)
#print(spm.Info.name())
#print(spm.SPMCommand().version)
# Out:
# 221202-14:01:25,388 nipype.utils WARNING:
# 	 A newer version (1.8.4) of nipy/nipype is available. You are using 1.7.1
# 221202-14:01:30,244 nipype.interface DEBUG:
# 	 matlab command or path has changed. recomputing version.
# 221202-14:01:30,253 nipype.interface DEBUG:
# 	 nodesktop_True
# 221202-14:01:30,255 nipype.interface DEBUG:
# 	 nosplash_True
# 221202-14:01:30,257 nipype.interface DEBUG:
# 	 single_comp_thread_True
# 221202-14:01:30,259 nipype.interface DEBUG:
# 	 nodesktop_True
# 221202-14:01:30,261 nipype.interface DEBUG:
# 	 nosplash_True
# 221202-14:01:30,263 nipype.interface DEBUG:
# 	 single_comp_thread_True

# %% [markdown]
# ### Neuropythy configuration
# On startup, neuropythy looks for file ~/.npythyrc. Here, we override these settings and environment variables

# %% [markdown]
# ### Specify important variables

# %%
wf_name = 'wf_laminar_fMRI_func_pRF'

UNI_id = 'UNI_corrected.nii'                                    # name of raw T1 UNI image
T1_id = 'T1.mgz'                                                # name of preprocessed T1 (output of structural processing pipeline)
# brainmask_id = 'brainmask.nii'
# GM_id = 'gm.mask_thresh.nii'
# WM_id = 'wm.mask_thresh.nii'

# manual correction files - from itksnap
coregT1_out_id = 'coregT1_out.nii'
# coreg_itksnap_struct2func_txt_id = 'coreg_itksnap_struct2func.txt'
# coreg_itksnap_struct2func_mat_id = 'coreg_itksnap_struct2func.mat'
coreg_itksnap_func2struct_txt_id = 'coreg_itksnap_func2struct.txt'
# coreg_itksnap_func2struct_mat_id = 'coreg_itksnap_func2struct.mat'

manual_midoccmask_id = 'midoccMask.nii'
manual_occipitalmask_id = 'occipitalMask.nii'

if fmap_method == 1:
    fmap_magnitude1_id = 'magnitude1.nii'
    fmap_magnitude2_id = 'magnitude2.nii'
    fmap_phasediff_id = 'phasediff.nii'
#elif fmap_method == 2:
    # implement

    
# THE LINES BELOW ARE STUDY-SPECIFIC (depend on acquired functional conditions)
n_dummy = 4                                                     # number of dummy scans to discard to allow for T1 equilibration

n_vol_bar1 = 124                                                # number of volumes of bar pRF mapping stimulus
n_vol_bar2 = n_vol_bar1                                         # number of volumes of bar pRF mapping stimulus
n_vol_ecc1 = 131                                                # number of volumes of ecc pRF mapping stimulus
n_vol_ecc2 = n_vol_ecc1                                         # number of volumes of ecc pRF mapping stimulus
n_vol_pol1 = 254                                                # number of volumes of pol pRF mapping stimulus
n_vol_pol2 = n_vol_pol1                                         # number of volumes of pol pRF mapping stimulus
n_vol_rs_ge = 50                                                # number of volumes of GE RS pRF mapping stimulus
n_vol_rs_se = 50                                                # number of volumes of SE RS pRF mapping stimulus

# iterables
subject_list = ['sub-01','sub-02','sub-03','sub-04']            # subject identifiers
sess_id_list = ['task-bar_run-01', 'task-bar_run-02',           # func session identifiers
             'task-pol_run-01', 'task-pol_run-02',
             'task-ecc_run-01', 'task-ecc_run-02',
             'rest_run-01']#, 'rest_run-02']
sess_nvol_list = [n_vol_bar1, n_vol_bar2,
                  n_vol_pol1, n_vol_pol2,
                  n_vol_ecc1, n_vol_ecc2,
                  n_vol_rs_ge]#, n_vol_rs_se]
sess_nr_list = list(range(0, len(sess_id_list)))

# %% [markdown]
# Get TR/TE/slice timing info from DICOM of sub-01
#
# Future improvement: don't hard-code this

# %%
fpath = opj(dicom_dir,'sub-01','MR bar_cmrr_mbep2d_bold_0p8_fov148_iPAT3_68_50sli_TR3000','MR000000.dcm')
dc = dcmread(fpath)

print(dc)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 196
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.34.18919.2019102111005792386547056
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.2
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_362'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC']
# (0008, 0012) Instance Creation Date              DA: '20191021'
# (0008, 0013) Instance Creation Time              TM: '110058.109000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.34.18919.2019102111005792386547056
# (0008, 0020) Study Date                          DA: '20191021'
# (0008, 0021) Series Date                         DA: '20191021'
# (0008, 0022) Acquisition Date                    DA: '20191021'
# (0008, 0023) Content Date                        DA: '20191021'
# (0008, 0030) Study Time                          TM: '095030.468000'
# (0008, 0031) Series Time                         TM: '105601.500000'
# (0008, 0032) Acquisition Time                    TM: '110057.205000'
# (0008, 0033) Content Time                        TM: '110058.109000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'MPI Leipzig'
# (0008, 0081) Institution Address                 ST: 'Stephanstrasse 1a,Leipzig-5B629E-,Leipzig,DE,04103'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'SEPTEMSYS'
# (0008, 1030) Study Description                   LO: '19883.56_191021_095030'
# (0008, 103e) Series Description                  LO: 'bar_cmrr_mbep2d_bold_0p8_fov148_iPAT3_6/8_50sli_TR3000'
# (0008, 1040) Institutional Department Name       LO: 'Department'
# (0008, 1050) Performing Physician's Name         PN: 'Neubert'
# (0008, 1070) Operators' Name                     PN: 'neubert@cbs.mpg.de'
# (0008, 1090) Manufacturer's Model Name           LO: 'Investigational_Device_7T'
# (0008, 1140)  Referenced Image Sequence  3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.34.18919.2019102110321098898700783
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.34.18919.2019102110320258371600696
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.34.18919.2019102110321098697700781
#    ---------
# (0010, 0010) Patient's Name                      PN: '19883.56'
# (0010, 0020) Patient ID                          LO: '19883.56'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '028Y'
# (0010, 1030) Patient's Weight                    DS: '51.0'
# (0010, 4000) Patient Comments                    LT: 'PHY-053'
# (0018, 0020) Scanning Sequence                   CS: 'EP'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SS']
# (0018, 0022) Scan Options                        CS: 'PFP'
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0024) Sequence Name                       SH: 'epfid2d1_184'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: '0.80000001192093'
# (0018, 0080) Repetition Time                     DS: '3000.0'
# (0018, 0081) Echo Time                           DS: '24.0'
# (0018, 0083) Number of Averages                  DS: '1.0'
# (0018, 0084) Imaging Frequency                   DS: '297.21795'
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: '1'
# (0018, 0087) Magnetic Field Strength             DS: '6.98'
# (0018, 0088) Spacing Between Slices              DS: '0.79999986499017'
# (0018, 0089) Number of Phase Encoding Steps      IS: '137'
# (0018, 0091) Echo Train Length                   IS: '1'
# (0018, 0093) Percent Sampling                    DS: '100.0'
# (0018, 0094) Percent Phase Field of View         DS: '100.0'
# (0018, 0095) Pixel Bandwidth                     DS: '1181.0'
# (0018, 1000) Device Serial Number                LO: '18919'
# (0018, 1020) Software Versions                   LO: 'syngo MR B17'
# (0018, 1030) Protocol Name                       LO: 'bar_cmrr_mbep2d_bold_0p8_fov148_iPAT3_6/8_50sli_TR3000'
# (0018, 1251) Transmit Coil Name                  SH: '32Ch_Head_7T'
# (0018, 1310) Acquisition Matrix                  US: [184, 0, 0, 184]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: '77.0'
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: '0.0540810211022'
# (0018, 1318) dB/dt                               DS: '0.0'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0019, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0019, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0019, 100a) [NumberOfImagesInMosaic]            US: 50
# (0019, 100b) [SliceMeasurementDuration]          DS: '45.0'
# (0019, 100f) [GradientMode]                      SH: 'Fast*'
# (0019, 1011) [FlowCompensation]                  SH: 'No'
# (0019, 1012) [TablePositionOrigin]               SL: [0, 0, -2350]
# (0019, 1013) [ImaAbsTablePosition]               SL: [0, 0, -2350]
# (0019, 1014) [ImaRelTablePosition]               IS: [0, 0, 0]
# (0019, 1015) [SlicePosition_PCS]                 FD: [-578.45888766, -130.14908948, 612.69339288]
# (0019, 1016) [TimeAfterStart]                    DS: '398.1175'
# (0019, 1017) [SliceResolution]                   DS: '1.0'
# (0019, 1018) [RealDwellTime]                     IS: '2300'
# (0019, 1028) [BandwidthPerPixelPhaseEncode]      FD: 16.304
# (0019, 1029) [MosaicRefAcqTimes]                 FD: Array of 50 elements
# (0020, 000d) Study Instance UID                  UI: 1.3.12.2.1107.5.2.34.18919.30000019102107503050000000001
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.34.18919.2019102110520033897428205.0.0.0
# (0020, 0010) Study ID                            SH: '1'
# (0020, 0011) Series Number                       IS: '7'
# (0020, 0012) Acquisition Number                  IS: '124'
# (0020, 0013) Instance Number                     IS: '124'
# (0020, 0032) Image Position (Patient)            DS: [-578.45888765572, -130.14908947552, 612.6933928839]
# (0020, 0037) Image Orientation (Patient)         DS: [0.99875689686157, 0.04513394625848, -0.0211562725117, -0.030159933771, 0.20925214721261, -0.977396499524]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.34.18919.1.20191021102800765.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: '24.707038946204'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1472
# (0028, 0011) Columns                             US: 1472
# (0028, 0030) Pixel Spacing                       DS: [0.80434781312943, 0.80434781312943]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 4095
# (0028, 1050) Window Center                       DS: '1088.0'
# (0028, 1051) Window Width                        DS: '2637.0'
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0029, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0029, 1009) [CSA Image Header Version]          LO: '20191021'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 11468 elements
# (0029, 1018) [CSA Series Header Type]            CS: 'MR'
# (0029, 1019) [CSA Series Header Version]         LO: '20191021'
# (0029, 1020) [CSA Series Header Info]            OB: Array of 104072 elements
# (0029, 1160) [Series Workflow Status]            LO: 'com'
# (0032, 1060) Requested Procedure Description     LO: 'TA_VB17 V2STRIPES-Haenelt'
# (0038, 0010) Admission ID                        LO: 'PHY-053'
# (0040, 0244) Performed Procedure Step Start Date DA: '20191021'
# (0040, 0245) Performed Procedure Step Start Time TM: '095050.921000'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR20191021095050'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'TA_VB17^V2STRIPES-Haenelt'
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0051, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0051, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0051, 100a) [Unknown]                           LO: 'TA 00.04'
# (0051, 100b) [AcquisitionMatrixText]             LO: '184p*184s'
# (0051, 100c) [Unknown]                           LO: 'FoV 1183*1183'
# (0051, 100e) [Unknown]                           LO: 'Cor>Tra(-12.2)>Sag(2.3)'
# (0051, 100f) [CoilString]                        LO: 'C:A32'
# (0051, 1011) [PATModeText]                       LO: 'p3'
# (0051, 1012) [Unknown]                           SH: 'TP 0'
# (0051, 1013) [PositivePCSDirections]             SH: '+LPH'
# (0051, 1016) [Unknown]                           LO: 'p3 M/ND/MOSAIC'
# (0051, 1017) [Unknown]                           SH: 'SL 0.8'
# (0051, 1019) [Unknown]                           LO: 'A1/PFP'
# (7fe0, 0010) Pixel Data                          OW: Array of 4333568 elements

# %%
# repetition time
TR = dc.RepetitionTime / 1000                               # in seconds [s]
TR_str = '%.1fs' % TR

# echo time
TE = dc.EchoTime / 1000                                     # in seconds [s]

# MR acquisition type
acquisition_type = dc.MRAcquisitionType

# slice acquisition times
slice_timing = dc[0x0019, 0x1029].value                      # in milliseconds [ms]
slice_timing[:] = [x / 1000 for x in slice_timing]            # in seconds [s]

# number of slices
num_slices = dc[0x0019, 0x100a].value

# time of volume acquisition
TA = TR-(TR/num_slices)

# %%
TR
# Out:
# 3.0

# %% [markdown]
# Get parameters needed for fieldmap correction (see: https://lcni.uoregon.edu/kb-articles/kb-0003)

# %%
# fpath = opj(dicom_dir,'sub-01','MR fieldmap_DeltaTE1p02ms','MR000000.dcm')
# dc = dcmread(fpath)

# print(dc)

# %%
# effective echo spacing 
bandwidth_per_pixel_phase_encode = dc[0x0019, 0x1028].value
acquisition_matrix_text = dc[0x0051, 0x100b].value
matrix_size_phase = float(re.search(r'\d+', acquisition_matrix_text).group())
                                    # NOTE: The size of the image in the phase direction 
                                    # is *usually* the first number in the field (0051, 100b), 
                                    # AcquisitionMatrixText. This is, however, not always the 
                                    # case, so it is better to determine the actual size 
                                    # (rows or columns) of your reconstructed image in the 
                                    # phase encode direction. You can also just read the 
                                    # effective echo spacing from the Series Info screen 
                                    # in MRIConvert if you are running the latest version.
effective_echo_spacing = 1/(bandwidth_per_pixel_phase_encode + matrix_size_phase)

# total readout time for an EPI sequence
total_readout_time = (matrix_size_phase - 1) * effective_echo_spacing

# deltaTE
delta_TE = 1.02                      # in milliseconds [ms]      
                                     # (a float, nipype default value: 2.46) 
                                     # echo time difference of the fieldmap 
                                     # sequence in ms. (usually 2.46ms in Siemens)

# %%
(bandwidth_per_pixel_phase_encode + matrix_size_phase)
# Out:
# 200.304

# %% [markdown]
# ### Create workflow
# About connecting nodes: https://nipype.readthedocs.io/en/0.11.0/users/joinnode_and_itersource.html

# %%
wf = Workflow(name=wf_name, base_dir=der_dir)

# %% [markdown]
# ### Subjects & functional sessions

# %%
subjects = Node(IdentityInterface(fields=['subject_id']),name='subjects')
subjects.iterables = [('subject_id', subject_list)]

# %%
sessions = Node(IdentityInterface(fields=['sess_id','sess_nvol','sess_nr']),name='sessions')
sessions.iterables = [('sess_id', sess_id_list), ('sess_nvol', sess_nvol_list), ('sess_nr', sess_nr_list)]
sessions.synchronize = True

# %% [markdown]
# ### Acquisition parameters

# %%
acquisitionParams = Node(IdentityInterface(fields=['n_dummy', 'TR'
                                                  'TA','TR_str','TE','acquisition_type',
                                                  'slice_timing','num_slices',
                                                  'effective_echo_spacing','total_readout_time',
                                                  'delta_TE']),
                         name='acquisitionParams')

acquisitionParams.inputs.n_dummy = n_dummy
acquisitionParams.inputs.TR = TR
acquisitionParams.inputs.TA = TA
acquisitionParams.inputs.TR_str = TR_str
acquisitionParams.inputs.TE = TE
acquisitionParams.inputs.acquisition_type = acquisition_type
acquisitionParams.inputs.slice_timing = slice_timing
acquisitionParams.inputs.num_slices = num_slices
acquisitionParams.inputs.effective_echo_spacing = effective_echo_spacing
acquisitionParams.inputs.total_readout_time = total_readout_time
acquisitionParams.inputs.delta_TE = delta_TE

# %% [markdown]
# ### Grab data
#
# DataGrabber is an interface for collecting files from hard drive. It is very flexible and supports almost any file organization of your data you can imagine.
# <br>More info: https://nipype.readthedocs.io/en/0.11.0/users/grabbing_and_sinking.html

# %% [markdown]
# #### Anatomical and field map data

# %%
datasource = Node(DataGrabber(infields=['subject_id'], outfields=['UNI', 'T1', 
                                                                  'fmap_magnitude1', 
                                                                  'fmap_magnitude2',
                                                                  'fmap_phasediff', 
                                                                  'subject_id']),
                 name='datasource')
datasource.inputs.base_directory = data_dir
datasource.inputs.sort_filelist = False
datasource.inputs.template = '*'
datasource.inputs.field_template = dict(UNI='output/anat/_subject_id_%s/'+UNI_id,
                                        T1='output/freesurfer_externalbrainmask/_subject_id_%s/'+T1_id,
                                        fmap_magnitude1='raw/%s/fmap/'+fmap_magnitude1_id,
                                        fmap_magnitude2='raw/%s/fmap/'+fmap_magnitude2_id,
                                        fmap_phasediff='raw/%s/fmap/'+fmap_phasediff_id
                                       )
datasource.inputs.template_args = dict(UNI=[['subject_id']],
                                       T1=[['subject_id']],
                                       fmap_magnitude1=[['subject_id']],
                                       fmap_magnitude2=[['subject_id']],
                                       fmap_phasediff=[['subject_id']]
                                       )

# %%
wf.connect([(subjects, datasource,[('subject_id', 'subject_id')])])
# Out:
# 221202-14:02:03,123 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.datasource): No edge data
# 221202-14:02:03,125 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.datasource): new edge data: {'connect': [('subject_id', 'subject_id')]}

# %% [markdown]
# ##### Convert T1.mgz to .nii

# %%
out_type = 'nii'

# %%
convertT1ToNii = Node(MRIConvert(out_type=out_type), name='convertT1ToNii')

# %%
wf.connect([(datasource,convertT1ToNii,[('T1', 'in_file')])])
# Out:
# 221202-14:02:03,162 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasource, wf_laminar_fMRI_func_pRF.convertT1ToNii): No edge data
# 221202-14:02:03,164 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasource, wf_laminar_fMRI_func_pRF.convertT1ToNii): new edge data: {'connect': [('T1', 'in_file')]}

# %% [markdown]
# #### Functional data

# %%
datasourceFunc = Node(DataGrabber(infields=['subject_id','sess_id'], outfields=['sess_id', 
                                                                  'subject_id']),
                 name='datasourceFunc')
datasourceFunc.inputs.base_directory = data_dir
datasourceFunc.inputs.sort_filelist = False
datasourceFunc.inputs.template = '*'
datasourceFunc.inputs.field_template = dict(sess_id='raw/%s/func/%s.nii'
                                       )
datasourceFunc.inputs.template_args = dict(sess_id=[['subject_id','sess_id']]
                                       )

# %%
wf.connect([(subjects, datasourceFunc, [('subject_id', 'subject_id')])])
wf.connect([(sessions, datasourceFunc, [('sess_id', 'sess_id')])])
# Out:
# 221202-14:02:03,191 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.datasourceFunc): No edge data
# 221202-14:02:03,193 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.datasourceFunc): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 221202-14:02:03,196 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.datasourceFunc): No edge data
# 221202-14:02:03,197 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.datasourceFunc): new edge data: {'connect': [('sess_id', 'sess_id')]}

# %% [markdown]
# #### Manual edits
# (if they exist)

# %%
datasourceManualEdits = Node(DataGrabber(infields=['subject_id'], outfields=[#'coreg_itksnap_struct2func_txt',
                                                                             #'coreg_itksnap_struct2func_mat',
                                                                             'coreg_itksnap_func2struct_txt',
                                                                             #'coreg_itksnap_func2struct_mat',
                                                                             'manual_midoccmask',
                                                                             'manual_occipitalmask',
                                                                             'subject_id']),
                 name='datasourceManualEdits')
datasourceManualEdits.inputs.base_directory = data_dir
datasourceManualEdits.inputs.sort_filelist = False
datasourceManualEdits.inputs.template = '*'
datasourceManualEdits.inputs.field_template = dict(#coreg_itksnap_struct2func_txt='manualcorr/func/_subject_id_%s/'+coreg_itksnap_struct2func_txt_id,
                                                   #coreg_itksnap_struct2func_mat='manualcorr/func/_subject_id_%s/'+coreg_itksnap_struct2func_mat_id,
                                                   coreg_itksnap_func2struct_txt='manualcorr/func/_subject_id_%s/'+coreg_itksnap_func2struct_txt_id,
                                                   #coreg_itksnap_func2struct_mat='manualcorr/func/_subject_id_%s/'+coreg_itksnap_func2struct_mat_id,
                                                   manual_midoccmask='manualcorr/func/_subject_id_%s/'+manual_midoccmask_id,
                                                   manual_occipitalmask='manualcorr/func/_subject_id_%s/'+manual_occipitalmask_id
                                       )
datasourceManualEdits.inputs.template_args = dict(#coreg_itksnap_struct2func_txt=[['subject_id']],
                                                  #coreg_itksnap_struct2func_mat=[['subject_id']],
                                                  coreg_itksnap_func2struct_txt=[['subject_id']],
                                                  #coreg_itksnap_func2struct_mat=[['subject_id']],
                                                  manual_midoccmask=[['subject_id']],
                                                  manual_occipitalmask=[['subject_id']]
                                       )

# %%
if manual_edits: 
    wf.connect([(subjects, datasourceManualEdits, [('subject_id', 'subject_id')])])
# Out:
# 221202-14:02:03,224 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.datasourceManualEdits): No edge data
# 221202-14:02:03,228 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.datasourceManualEdits): new edge data: {'connect': [('subject_id', 'subject_id')]}

# %% [markdown]
# ### Calculate field map
#
# Using fsl_prepare_fieldmap.
#
# "If you have data from a SIEMENS scanner then we strongly recommend that the tool fsl_prepare_fieldmap is used to generate the required input data for FEAT or fugue. Fieldmap data from a SIEMENS scanner takes the form of one phase difference image and two magnitude images (one for each echo time). In the following, where a magnitude image is required, pick the "best looking" one. This image is used for registration and masking but the process is not particularly sensitive to the quality and typically either image will work fine.
#
# Brain extraction of the magnitude image is very important and must be tight - that is, it must exclude all non-brain voxels and any voxels with only a small partial volume contribution. The reason for this is that these areas are normally very noisy in the phase image (look at them in FSLView - if they are not noisy then this is not so important). It is crucial that the mask (derived from this brain extracted image) contains few of these noisy voxels. This is most easily done by making the brain extraction very tight, erring on excluding brain voxels. The exclusion of brain voxels in this instance is actually fine and will have no repercussions, since the fieldmap is extrapolated beyond this mask, and that is the only purpose that the mask plays. Therefore make sure your mask is (if it can't be perfect) too small. As noted above, either magnitude image (from the different echos) can normally be used here - it is not that important."
#
# Source: https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FUGUE/Guide#SIEMENS_data

# %% [markdown]
# #### Brain extract magnitude image
# Use magnitude1.nii by default

# %%
# FSL BET - run on magnitude1.nii image
betMagnImg = Node(BET(),name='betMagnImg')
# Out:
# 221202-14:02:03,242 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI

# %%
wf.connect([(datasource,betMagnImg,[('fmap_magnitude1','in_file')])])
# Out:
# 221202-14:02:03,256 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasource, wf_laminar_fMRI_func_pRF.betMagnImg): No edge data
# 221202-14:02:03,258 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasource, wf_laminar_fMRI_func_pRF.betMagnImg): new edge data: {'connect': [('fmap_magnitude1', 'in_file')]}

# %% [markdown]
# #### Prepare field map
#
# Prepares a fieldmap suitable for FEAT from SIEMENS data - saves output in rad/s format (e.g. `fsl_prepare_fieldmap SIEMENS images_3_gre_field_mapping images_4_gre_field_mapping fmap_rads 2.65`).
#
#
# [Mandatory]
# delta_TE: (a float, nipype default value: 2.46)
#         echo time difference of the fieldmap sequence in ms. (usually 2.46ms
#         in Siemens)
#         flag: %f, position: -2
# in_magnitude: (an existing file name)
#         Magnitude difference map, brain extracted
#         flag: %s, position: 3
# in_phase: (an existing file name)
#         Phase difference map, in SIEMENS format range from 0-4096 or 0-8192)
#         flag: %s, position: 2
#
#
# https://nipype.readthedocs.io/en/0.12.1/interfaces/generated/nipype.interfaces.fsl.epi.html#preparefieldmap

# %%
if unwarp:
    prepFieldMap = Node(PrepareFieldmap(), name='prepFieldMap')

# %%
if unwarp:
    wf.connect([(acquisitionParams,prepFieldMap,[('delta_TE','delta_TE')])])
    wf.connect([(betMagnImg,prepFieldMap,[('out_file','in_magnitude')])])
    wf.connect([(datasource,prepFieldMap,[('fmap_phasediff','in_phase')])])

# %% [markdown]
# ### Discard initial fMRI volumes to allow for T1 equilibration

# %%
discardDummies = Node(ExtractROI(t_min=n_dummy), name='discardDummies')
# Out:
# 221202-14:02:03,295 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI

# %%
wf.connect([(datasourceFunc, discardDummies,[('sess_id', 'in_file')])])
wf.connect([(sessions, discardDummies,[('sess_nvol', 't_size')])])
# Out:
# 221202-14:02:03,308 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasourceFunc, wf_laminar_fMRI_func_pRF.discardDummies): No edge data
# 221202-14:02:03,309 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasourceFunc, wf_laminar_fMRI_func_pRF.discardDummies): new edge data: {'connect': [('sess_id', 'in_file')]}
# 221202-14:02:03,310 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.discardDummies): No edge data
# 221202-14:02:03,311 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.discardDummies): new edge data: {'connect': [('sess_nvol', 't_size')]}

# %% [markdown]
# ### Realignment: head-motion estimation and correction (FSL MCFLIRT)
# https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/MCFLIRT
#
# https://nipype.readthedocs.io/en/0.12.1/interfaces/generated/nipype.interfaces.fsl.preprocess.html
#
# citation: Jenkinson, M., Bannister, P., Brady, J. M. and Smith, S. M. Improved Optimisation for the Robust and Accurate Linear Registration and Motion Correction of Brain Images. NeuroImage, 17(2), 825-841, 2002.
#
# First, motion-correction with MCFLIRT, within each session, saving the resulting transformation matrices. Then, concatenate the mean runs from each session and realign to each other with MCFLIRT, saving the transformation matrices. Loop through each matrix in the MCFLIRT output and do 'convert_xfm -omat CONCAT_0000 -concat reg_series1_to_series2.mat MAT_0000' for all MAT* files, then use applyxfm4D, with the "-userprefix CONCAT_" option. This does all transformations at once, directly from the original data and minimizes interpolation effects. Based on: https://www.jiscmail.ac.uk/cgi-bin/webadmin?A2=fsl;21c97ca8.06
#
# #### Within sessions

# %%
mean_vol = True             # (a boolean) register to mean volume
save_mats = True             # (a boolean) save transformation parameters

# %%
mcflirtWithinSess = Node(MCFLIRT(mean_vol = mean_vol, save_mats=save_mats), 
               name='mcflirtWithinSess')
# Out:
# 221202-14:02:03,336 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI

# %%
wf.connect([(discardDummies, mcflirtWithinSess,[('roi_file','in_file')])])
# Out:
# 221202-14:02:03,350 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.discardDummies, wf_laminar_fMRI_func_pRF.mcflirtWithinSess): No edge data
# 221202-14:02:03,351 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.discardDummies, wf_laminar_fMRI_func_pRF.mcflirtWithinSess): new edge data: {'connect': [('roi_file', 'in_file')]}

# %%
#fsl.MCFLIRT.help()

# %% [markdown]
# #### Between sessions
# ##### Concatenate mean runs

# %%
dimension = 't'
output_type = 'NIFTI'
merged_file = 'merged_means.nii'

# %%
concatenateMeans = JoinNode(Merge(dimension=dimension, output_type=output_type, merged_file=merged_file),
                        joinfield='in_files',
                        joinsource='sessions',
                        name="concatenateMeans")
# Out:
# 221202-14:02:03,388 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# 221202-14:02:03,389 nipype.workflow DEBUG:
# 	 Converted the join node concatenateMeans field in_files trait type from a legal value to a pathlike object or string representing an existing file

# %%
wf.connect([(mcflirtWithinSess, concatenateMeans,[('mean_img', 'in_files')])])
# Out:
# 221202-14:02:03,405 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.mcflirtWithinSess, wf_laminar_fMRI_func_pRF.concatenateMeans): No edge data
# 221202-14:02:03,406 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.mcflirtWithinSess, wf_laminar_fMRI_func_pRF.concatenateMeans): new edge data: {'connect': [('mean_img', 'in_files')]}

# %% [markdown]
# ##### MCFLIRT on merged mean runs

# %%
mean_vol = True               # (a boolean) register to mean volume
save_mats = True               # (a boolean) save transformation parameters

# %%
mcflirtBetweenSess = Node(MCFLIRT(mean_vol = mean_vol, save_mats=save_mats), 
               name='mcflirtBetweenSess')
# Out:
# 221202-14:02:03,430 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI

# %%
wf.connect([(concatenateMeans, mcflirtBetweenSess,[('merged_file','in_file')])])
# Out:
# 221202-14:02:03,444 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.concatenateMeans, wf_laminar_fMRI_func_pRF.mcflirtBetweenSess): No edge data
# 221202-14:02:03,445 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.concatenateMeans, wf_laminar_fMRI_func_pRF.mcflirtBetweenSess): new edge data: {'connect': [('merged_file', 'in_file')]}

# %%
MCFLIRT.help()
# Out:
# Wraps the executable command ``mcflirt``.
#
# FSL MCFLIRT wrapper for within-modality motion correction
#
# For complete details, see the `MCFLIRT Documentation.
# <https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/MCFLIRT>`_
#
# Examples
# --------
# >>> from nipype.interfaces import fsl
# >>> mcflt = fsl.MCFLIRT()
# >>> mcflt.inputs.in_file = 'functional.nii'
# >>> mcflt.inputs.cost = 'mutualinfo'
# >>> mcflt.inputs.out_file = 'moco.nii'
# >>> mcflt.cmdline
# 'mcflirt -in functional.nii -cost mutualinfo -out moco.nii'
# >>> res = mcflt.run()  # doctest: +SKIP
#
# Inputs::
#
#         [Mandatory]
#         in_file: (a pathlike object or string representing an existing file)
#                 timeseries to motion-correct
#                 argument: ``-in %s``, position: 0
#
#         [Optional]
#         out_file: (a pathlike object or string representing a file)
#                 file to write
#                 argument: ``-out %s``
#         cost: ('mutualinfo' or 'woods' or 'corratio' or 'normcorr' or
#                   'normmi' or 'leastsquares')
#                 cost function to optimize
#                 argument: ``-cost %s``
#         bins: (an integer)
#                 number of histogram bins
#                 argument: ``-bins %d``
#         dof: (an integer)
#                 degrees of freedom for the transformation
#                 argument: ``-dof %d``
#         ref_vol: (an integer)
#                 volume to align frames to
#                 argument: ``-refvol %d``
#         scaling: (a float)
#                 scaling factor to use
#                 argument: ``-scaling %.2f``
#         smooth: (a float)
#                 smoothing factor for the cost function
#                 argument: ``-smooth %.2f``
#         rotation: (an integer)
#                 scaling factor for rotation tolerances
#                 argument: ``-rotation %d``
#         stages: (an integer)
#                 stages (if 4, perform final search with sinc interpolation
#                 argument: ``-stages %d``
#         init: (a pathlike object or string representing an existing file)
#                 inital transformation matrix
#                 argument: ``-init %s``
#         interpolation: ('spline' or 'nn' or 'sinc')
#                 interpolation method for transformation
#                 argument: ``-%s_final``
#         use_gradient: (a boolean)
#                 run search on gradient images
#                 argument: ``-gdt``
#         use_contour: (a boolean)
#                 run search on contour images
#                 argument: ``-edge``
#         mean_vol: (a boolean)
#                 register to mean volume
#                 argument: ``-meanvol``
#         stats_imgs: (a boolean)
#                 produce variance and std. dev. images
#                 argument: ``-stats``
#         save_mats: (a boolean)
#                 save transformation matrices
#                 argument: ``-mats``
#         save_plots: (a boolean)
#                 save transformation parameters
#                 argument: ``-plots``
#         save_rms: (a boolean)
#                 save rms displacement parameters
#                 argument: ``-rmsabs -rmsrel``
#         ref_file: (a pathlike object or string representing an existing file)
#                 target image for motion correction
#                 argument: ``-reffile %s``
#         output_type: ('NIFTI' or 'NIFTI_PAIR' or 'NIFTI_GZ' or
#                   'NIFTI_PAIR_GZ')
#                 FSL output type
#         args: (a string)
#                 Additional parameters to the command
#                 argument: ``%s``
#         environ: (a dictionary with keys which are a bytes or None or a value
#                   of class 'str' and with values which are a bytes or None or a
#                   value of class 'str', nipype default value: {})
#                 Environment variables
#
# Outputs::
#
#         out_file: (a pathlike object or string representing an existing file)
#                 motion-corrected timeseries
#         variance_img: (a pathlike object or string representing an existing
#                   file)
#                 variance image
#         std_img: (a pathlike object or string representing an existing file)
#                 standard deviation image
#         mean_img: (a pathlike object or string representing an existing file)
#                 mean timeseries image (if mean_vol=True)
#         par_file: (a pathlike object or string representing an existing file)
#                 text-file with motion parameters
#         mat_file: (a list of items which are a pathlike object or string
#                   representing an existing file)
#                 transformation matrices
#         rms_files: (a list of items which are a pathlike object or string
#                   representing an existing file)
#                 absolute and relative displacement parameters
#
# References:
# -----------
# None

# %% [markdown]
# ##### Concatenate transformation matrices

# %% [markdown]
# Select given session's transformation mat

# %%
betweenMat = Node(Select(), name='betweenMat')

# %%
wf.connect([(mcflirtBetweenSess, betweenMat, [('mat_file', 'inlist')])])
wf.connect([(sessions, betweenMat, [('sess_nr', 'index')])])
# Out:
# 221202-14:02:03,487 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.mcflirtBetweenSess, wf_laminar_fMRI_func_pRF.betweenMat): No edge data
# 221202-14:02:03,488 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.mcflirtBetweenSess, wf_laminar_fMRI_func_pRF.betweenMat): new edge data: {'connect': [('mat_file', 'inlist')]}
# 221202-14:02:03,489 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.betweenMat): No edge data
# 221202-14:02:03,489 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.betweenMat): new edge data: {'connect': [('sess_nr', 'index')]}

# %% [markdown]
# Concatenate within-session mat_files with corresponding session's between-session realignment mat_file

# %%
concat_xfm = True         # (a boolean) write joint transformation of two input matrices
                          # flag: -concat, position: -3
                          # mutually_exclusive: invert_xfm, concat_xfm, fix_scale_skew
                          # requires: in_file2

# %%
concatenateTransforms = MapNode(ConvertXFM(concat_xfm=concat_xfm),
                            name = 'concatenateTransforms', iterfield=['in_file2'])
# Out:
# 221202-14:02:03,514 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# 221202-14:02:03,516 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file2

# %%
wf.connect([(betweenMat,concatenateTransforms,[('out','in_file')])])
wf.connect([(mcflirtWithinSess,concatenateTransforms,[('mat_file','in_file2')])])
# Out:
# 221202-14:02:03,533 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.betweenMat, wf_laminar_fMRI_func_pRF.concatenateTransforms): No edge data
# 221202-14:02:03,534 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.betweenMat, wf_laminar_fMRI_func_pRF.concatenateTransforms): new edge data: {'connect': [('out', 'in_file')]}
# 221202-14:02:03,535 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.mcflirtWithinSess, wf_laminar_fMRI_func_pRF.concatenateTransforms): No edge data
# 221202-14:02:03,536 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.mcflirtWithinSess, wf_laminar_fMRI_func_pRF.concatenateTransforms): new edge data: {'connect': [('mat_file', 'in_file2')]}

# %%
#ConvertXFM.help()

# %% [markdown]
# Put all transformation matrices for given session in one folder
#
# (Not the most elegant solution, but ApplyXfm4D requires a directory of tranformation mat files as input)

# %%
def copy_transforms(subject_id,sess_id,sess_nr,sess_nvol,mat_files,working_dir):
    from os.path import join as opj
    import shutil
    import os
    
    transformMatDir = opj(working_dir,'_subject_id_'+subject_id,
                         '_sess_id_'+sess_id+'_sess_nr_'+str(sess_nr)+'_sess_nvol_'+str(sess_nvol),
                         'transformMats')
    
    if not os.path.isdir(transformMatDir):
        os.mkdir(transformMatDir)
    
    for mat in mat_files:
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
        print(mat)
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')

        # copy file
        shutil.copy(mat, transformMatDir)
        
        # remove .mat extension (this is how the ApplyXfm4D interface likes it)
        base=os.path.basename(mat)
        filename=os.path.splitext(base)[0]
        shutil.move(opj(transformMatDir,filename+'.mat'), opj(transformMatDir,filename)) 

    # session-dependent filename prefix
    prefix = f"MAT_000{sess_nr}_MAT_"

    return transformMatDir, prefix

# %%
copyTransforms = Node(Function(input_names = ['subject_id','sess_id','sess_nr', 'sess_nvol',
                                             'mat_files','working_dir'],
                               output_names=['transformMatDir','prefix'],
                               function=copy_transforms),
                      name='copyTransforms')
copyTransforms.inputs.working_dir = opj(der_dir,wf_name)

# %%
wf.connect([(subjects, copyTransforms, [('subject_id', 'subject_id')])])
wf.connect([(sessions, copyTransforms, [('sess_id', 'sess_id')])])
wf.connect([(sessions, copyTransforms, [('sess_nr', 'sess_nr')])])
wf.connect([(sessions, copyTransforms, [('sess_nvol', 'sess_nvol')])])
wf.connect([(concatenateTransforms, copyTransforms, [('out_file', 'mat_files')])])
# Out:
# 221202-14:02:03,593 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.copyTransforms): No edge data
# 221202-14:02:03,594 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.copyTransforms): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 221202-14:02:03,595 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.copyTransforms): No edge data
# 221202-14:02:03,596 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.copyTransforms): new edge data: {'connect': [('sess_id', 'sess_id')]}
# 221202-14:02:03,597 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.copyTransforms): Edge data exists: {'connect': [('sess_id', 'sess_id')]}
# 221202-14:02:03,597 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.copyTransforms): new edge data: {'connect': [('sess_id', 'sess_id'), ('sess_nr', 'sess_nr')]}
# 221202-14:02:03,598 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.copyTransforms): Edge data exists: {'connect': [('sess_id', 'sess_id'), ('sess_nr', 'sess_nr')]}
# 221202-14:02:03,599 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.copyTransforms): new edge data: {'connect': [('sess_id', 'sess_id'), ('sess_nr', 'sess_nr'), ('sess_nvol', 'sess_nvol')]}
# 221202-14:02:03,600 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.concatenateTransforms, wf_laminar_fMRI_func_pRF.copyTransforms): No edge data
# 221202-14:02:03,600 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.concatenateTransforms, wf_laminar_fMRI_func_pRF.copyTransforms): new edge data: {'connect': [('out_file', 'mat_files')]}

# %% [markdown]
# Apply transformation matrices to realign within and between sessions in one step

# %%
applyRealign = Node(ApplyXfm4D(),name='applyRealign')
# Out:
# 221202-14:02:03,616 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI

# %%
wf.connect([(discardDummies,applyRealign,[('roi_file','in_file')])])
wf.connect([(discardDummies,applyRealign,[('roi_file','ref_vol')])])
wf.connect([(copyTransforms,applyRealign,[('transformMatDir','trans_dir')])])
wf.connect([(copyTransforms,applyRealign,[('prefix','user_prefix')])])
# Out:
# 221202-14:02:03,633 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.discardDummies, wf_laminar_fMRI_func_pRF.applyRealign): No edge data
# 221202-14:02:03,634 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.discardDummies, wf_laminar_fMRI_func_pRF.applyRealign): new edge data: {'connect': [('roi_file', 'in_file')]}
# 221202-14:02:03,635 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.discardDummies, wf_laminar_fMRI_func_pRF.applyRealign): Edge data exists: {'connect': [('roi_file', 'in_file')]}
# 221202-14:02:03,635 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.discardDummies, wf_laminar_fMRI_func_pRF.applyRealign): new edge data: {'connect': [('roi_file', 'in_file'), ('roi_file', 'ref_vol')]}
# 221202-14:02:03,636 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.copyTransforms, wf_laminar_fMRI_func_pRF.applyRealign): No edge data
# 221202-14:02:03,637 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.copyTransforms, wf_laminar_fMRI_func_pRF.applyRealign): new edge data: {'connect': [('transformMatDir', 'trans_dir')]}
# 221202-14:02:03,637 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.copyTransforms, wf_laminar_fMRI_func_pRF.applyRealign): Edge data exists: {'connect': [('transformMatDir', 'trans_dir')]}
# 221202-14:02:03,638 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.copyTransforms, wf_laminar_fMRI_func_pRF.applyRealign): new edge data: {'connect': [('transformMatDir', 'trans_dir'), ('prefix', 'user_prefix')]}

# %%
#ApplyXfm4D.help()

# %% [markdown]
# ### Unwarping
#
# fugue (FMRIB's Utility for Geometrically Unwarping EPIs) performs unwarping of an EPI image based on fieldmap data. The input required consists of the EPI image, the fieldmap (as an unwrapped phase map or a scaled fieldmap in rad/s) and appropriate image sequence parameters for the EPI and fieldmap acquisitions: the dwell time for EPI (also known as the echo spacing); and the echo time difference (called asym time herein).
#
# https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FUGUE/Guide
#
# https://nipype.readthedocs.io/en/0.12.0/interfaces/generated/nipype.interfaces.fsl.preprocess.html#fugue

# %%
if unwarp: 
    unwarping = Node(FUGUE(),name='unwarping')

# fugue -i epi --dwell=dwelltime --loadfmap=fieldmap -u result

# %%
if unwarp:
    wf.connect([(applyRealign,unwarping,[('out_file','in_file')])])
    wf.connect([(acquisitionParams,unwarping,[('effective_echo_spacing','dwell_time')])])
    wf.connect([(prepFieldMap,unwarping,[('out_fieldmap','fmap_in_file')])])

# %% [markdown]
# ### Slice-timing correction (SPM)
#
# Parker & Razlighi, 2019: "The Benefit of Slice Timing Correction in Common fMRI Preprocessing Pipelines."
# https://www.frontiersin.org/articles/10.3389/fnins.2019.00821/full

# %%
ref_slice = 1                           # (an integer (int or long))
                                        # 1-based Number of the reference slice

# %%
sliceTimingCorr = Node(SliceTiming(ref_slice=ref_slice),name='sliceTimingCorr')
# Out:
# 221202-14:02:03,701 nipype.interface DEBUG:
# 	 matlab command or path has changed. recomputing version.
# 221202-14:02:03,708 nipype.interface DEBUG:
# 	 nodesktop_True
# 221202-14:02:03,709 nipype.interface DEBUG:
# 	 nosplash_True
# 221202-14:02:03,709 nipype.interface DEBUG:
# 	 single_comp_thread_True
# 221202-14:02:03,710 nipype.interface DEBUG:
# 	 nodesktop_True
# 221202-14:02:03,711 nipype.interface DEBUG:
# 	 nosplash_True
# 221202-14:02:03,711 nipype.interface DEBUG:
# 	 single_comp_thread_True
# 221202-14:02:43,825 nipype.interface DEBUG:
# 	 Command:
# matlab -nodesktop -nosplash -nodesktop -nosplash -singleCompThread -r "fprintf(1,'Executing code at %s:\n',datestr(now));fprintf(1,'Executing code at %s:\n',datestr(now));ver,try,,if isempty(which('spm')),,throw(MException('SPMCheck:NotFound','SPM not in matlab path'));,end;,spm_path = spm('dir');,[name, version] = spm('ver');,fprintf(1, 'NIPYPE path:%s|name:%s|release:%s', spm_path, name, version);,exit;,        ,catch ME,fprintf(2,'MATLAB code threw an exception:\n');fprintf(2,'%s\n',ME.message);if length(ME.stack) ~= 0, fprintf(2,'File:%s\nName:%s\nLine:%d\n',ME.stack.file,ME.stack.name,ME.stack.line);, end;end;;exit"
# Standard output:
# MATLAB is selecting SOFTWARE OPENGL rendering.
# Opening log file:  /home/mayaaj90/java.log.27194
#
#                             < M A T L A B (R) >
#                   Copyright 1984-2021 The MathWorks, Inc.
#                   R2021a (9.10.0.1602886) 64-bit (glnxa64)
#                              February 17, 2021
#
#
# To get started, type doc.
# For product information, visit www.mathworks.com.
#
# Executing code at 02-Dec-2022 14:02:33:
# Executing code at 02-Dec-2022 14:02:34:
# -----------------------------------------------------------------------------------------------------
# MATLAB Version: 9.10.0.1602886 (R2021a)
# MATLAB License Number: 40871342
# Operating System: Linux 3.10.0-1160.76.1.el7.x86_64 #1 SMP Wed Aug 10 16:21:17 UTC 2022 x86_64
# Java Version: Java 1.8.0_202-b08 with Oracle Corporation Java HotSpot(TM) 64-Bit Server VM mixed mode
# -----------------------------------------------------------------------------------------------------
# MATLAB                                                Version 9.10        (R2021a)
# Simulink                                              Version 10.3        (R2021a)
# 5G Toolbox                                            Version 2.2         (R2021a)
# AUTOSAR Blockset                                      Version 2.4         (R2021a)
# Aerospace Blockset                                    Version 5.0         (R2021a)
# Aerospace Toolbox                                     Version 4.0         (R2021a)
# Antenna Toolbox                                       Version 5.0         (R2021a)
# Audio Toolbox                                         Version 3.0         (R2021a)
# Automated Driving Toolbox                             Version 3.3         (R2021a)
# Bioinformatics Toolbox                                Version 4.15.1      (R2021a)
# Communications Toolbox                                Version 7.5         (R2021a)
# Computer Vision Toolbox                               Version 10.0        (R2021a)
# Control System Toolbox                                Version 10.10       (R2021a)
# Curve Fitting Toolbox                                 Version 3.5.13      (R2021a)
# DDS Blockset                                          Version 1.0         (R2021a)
# DSP System Toolbox                                    Version 9.12        (R2021a)
# Database Toolbox                                      Version 10.1        (R2021a)
# Datafeed Toolbox                                      Version 6.0         (R2021a)
# Deep Learning HDL Toolbox                             Version 1.1         (R2021a)
# Deep Learning Toolbox                                 Version 14.2        (R2021a)
# Econometrics Toolbox                                  Version 5.6         (R2021a)
# Embedded Coder                                        Version 7.6         (R2021a)
# Filter Design HDL Coder                               Version 3.1.9       (R2021a)
# Financial Instruments Toolbox                         Version 3.2         (R2021a)
# Financial Toolbox                                     Version 6.1         (R2021a)
# Fixed-Point Designer                                  Version 7.2         (R2021a)
# Fuzzy Logic Toolbox                                   Version 2.8.1       (R2021a)
# GPU Coder                                             Version 2.1         (R2021a)
# Global Optimization Toolbox                           Version 4.5         (R2021a)
# HDL Coder                                             Version 3.18        (R2021a)
# HDL Verifier                                          Version 6.3         (R2021a)
# Image Acquisition Toolbox                             Version 6.4         (R2021a)
# Image Processing Toolbox                              Version 11.3        (R2021a)
# Instrument Control Toolbox                            Version 4.4         (R2021a)
# LTE Toolbox                                           Version 3.5         (R2021a)
# Lidar Toolbox                                         Version 1.1         (R2021a)
# MATLAB Coder                                          Version 5.2         (R2021a)
# MATLAB Compiler                                       Version 8.2         (R2021a)
# MATLAB Compiler SDK                                   Version 6.10        (R2021a)
# MATLAB Report Generator                               Version 5.10        (R2021a)
# Mapping Toolbox                                       Version 5.1         (R2021a)
# Mixed-Signal Blockset                                 Version 2.0         (R2021a)
# Model Predictive Control Toolbox                      Version 7.1         (R2021a)
# Motor Control Blockset                                Version 1.2         (R2021a)
# Navigation Toolbox                                    Version 2.0         (R2021a)
# Optimization Toolbox                                  Version 9.1         (R2021a)
# Parallel Computing Toolbox                            Version 7.4         (R2021a)
# Partial Differential Equation Toolbox                 Version 3.6         (R2021a)
# Phased Array System Toolbox                           Version 4.5         (R2021a)
# Powertrain Blockset                                   Version 1.9         (R2021a)
# Predictive Maintenance Toolbox                        Version 2.3         (R2021a)
# RF Blockset                                           Version 8.1         (R2021a)
# RF Toolbox                                            Version 4.1         (R2021a)
# ROS Toolbox                                           Version 1.3         (R2021a)
# Radar Toolbox                                         Version 1.0         (R2021a)
# Reinforcement Learning Toolbox                        Version 2.0         (R2021a)
# Risk Management Toolbox                               Version 1.9         (R2021a)
# Robotics System Toolbox                               Version 3.3         (R2021a)
# Robust Control Toolbox                                Version 6.10        (R2021a)
# Satellite Communications Toolbox                      Version 1.0         (R2021a)
# Sensor Fusion and Tracking Toolbox                    Version 2.1         (R2021a)
# SerDes Toolbox                                        Version 2.1         (R2021a)
# Signal Processing Toolbox                             Version 8.6         (R2021a)
# SimBiology                                            Version 6.1         (R2021a)
# SimEvents                                             Version 5.10        (R2021a)
# Simscape                                              Version 5.1         (R2021a)
# Simscape Driveline                                    Version 3.3         (R2021a)
# Simscape Electrical                                   Version 7.5         (R2021a)
# Simscape Fluids                                       Version 3.2         (R2021a)
# Simscape Multibody                                    Version 7.3         (R2021a)
# Simulink 3D Animation                                 Version 9.2         (R2021a)
# Simulink Check                                        Version 5.1         (R2021a)
# Simulink Code Inspector                               Version 3.8         (R2021a)
# Simulink Coder                                        Version 9.5         (R2021a)
# Simulink Compiler                                     Version 1.2         (R2021a)
# Simulink Control Design                               Version 5.7         (R2021a)
# Simulink Coverage                                     Version 5.2         (R2021a)
# Simulink Design Optimization                          Version 3.9.1       (R2021a)
# Simulink Design Verifier                              Version 4.5         (R2021a)
# Simulink PLC Coder                                    Version 3.4         (R2021a)
# Simulink Report Generator                             Version 5.10        (R2021a)
# Simulink Requirements                                 Version 1.7         (R2021a)
# Simulink Test                                         Version 3.4         (R2021a)
# SoC Blockset                                          Version 1.4         (R2021a)
# Stateflow                                             Version 10.4        (R2021a)
# Statistics and Machine Learning Toolbox               Version 12.1        (R2021a)
# Symbolic Math Toolbox                                 Version 8.7         (R2021a)
# System Composer                                       Version 2.0         (R2021a)
# System Identification Toolbox                         Version 9.14        (R2021a)
# Text Analytics Toolbox                                Version 1.7         (R2021a)
# UAV Toolbox                                           Version 1.1         (R2021a)
# Vehicle Dynamics Blockset                             Version 1.6         (R2021a)
# Vehicle Network Toolbox                               Version 5.0         (R2021a)
# Vision HDL Toolbox                                    Version 2.3         (R2021a)
# WLAN Toolbox                                          Version 3.2         (R2021a)
# Wavelet Toolbox                                       Version 5.6         (R2021a)
# Wireless HDL Toolbox                                  Version 2.2         (R2021a)
# Standard error:
# MATLAB code threw an exception:
# SPM not in matlab path
# Return code: 0

# %%
if unwarp:
    wf.connect([(unwarping,sliceTimingCorr,[('unwarped_file','in_files')])])
else:
    wf.connect([(applyRealign,sliceTimingCorr,[('out_file','in_files')])])
wf.connect([(acquisitionParams,sliceTimingCorr,[('num_slices','num_slices')])])
wf.connect([(acquisitionParams,sliceTimingCorr,[('slice_timing','slice_order')])])
wf.connect([(acquisitionParams,sliceTimingCorr,[('TR','time_repetition')])])
wf.connect([(acquisitionParams,sliceTimingCorr,[('TA','time_acquisition')])])
# Out:
# 221202-14:02:43,920 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyRealign, wf_laminar_fMRI_func_pRF.sliceTimingCorr): No edge data
# 221202-14:02:43,923 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyRealign, wf_laminar_fMRI_func_pRF.sliceTimingCorr): new edge data: {'connect': [('out_file', 'in_files')]}
# 221202-14:02:43,928 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.acquisitionParams, wf_laminar_fMRI_func_pRF.sliceTimingCorr): No edge data
# 221202-14:02:43,930 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.acquisitionParams, wf_laminar_fMRI_func_pRF.sliceTimingCorr): new edge data: {'connect': [('num_slices', 'num_slices')]}
# 221202-14:02:43,932 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.acquisitionParams, wf_laminar_fMRI_func_pRF.sliceTimingCorr): Edge data exists: {'connect': [('num_slices', 'num_slices')]}
# 221202-14:02:43,933 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.acquisitionParams, wf_laminar_fMRI_func_pRF.sliceTimingCorr): new edge data: {'connect': [('num_slices', 'num_slices'), ('slice_timing', 'slice_order')]}
# 221202-14:02:43,936 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.acquisitionParams, wf_laminar_fMRI_func_pRF.sliceTimingCorr): Edge data exists: {'connect': [('num_slices', 'num_slices'), ('slice_timing', 'slice_order')]}
# 221202-14:02:43,939 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.acquisitionParams, wf_laminar_fMRI_func_pRF.sliceTimingCorr): new edge data: {'connect': [('num_slices', 'num_slices'), ('slice_timing', 'slice_order'), ('TR', 'time_repetition')]}
# 221202-14:02:43,941 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.acquisitionParams, wf_laminar_fMRI_func_pRF.sliceTimingCorr): Edge data exists: {'connect': [('num_slices', 'num_slices'), ('slice_timing', 'slice_order'), ('TR', 'time_repetition')]}
# 221202-14:02:43,943 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.acquisitionParams, wf_laminar_fMRI_func_pRF.sliceTimingCorr): new edge data: {'connect': [('num_slices', 'num_slices'), ('slice_timing', 'slice_order'), ('TR', 'time_repetition'), ('TA', 'time_acquisition')]}

# %%
#SliceTiming.help()

# %% [markdown]
# ### Co-registration of functional and structural data (FreeSurfer bbregister, FLIRT FSL)
#
# Note: structural data is brought into functional space to avoid superfluous interpolation of functional volumes!
#
# https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FLIRT
#
# https://nipype.readthedocs.io/en/0.12.0/interfaces/generated/nipype.interfaces.fsl.preprocess.html#flirt

# %% [markdown]
# #### Concatenate functional runs

# %%
dimension = 't'
output_type = 'NIFTI'
merged_file = 'merged_func.nii'

# %%
concatenateFunc = JoinNode(Merge(dimension=dimension, output_type=output_type, merged_file=merged_file),
                        joinfield='in_files',
                        joinsource='sessions',
                        name="concatenateFunc")
# Out:
# 221202-14:02:43,978 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# 221202-14:02:43,981 nipype.workflow DEBUG:
# 	 Converted the join node concatenateFunc field in_files trait type from a legal value to a pathlike object or string representing an existing file

# %%
wf.connect([(sliceTimingCorr, concatenateFunc,[('timecorrected_files', 'in_files')])])
# Out:
# 221202-14:02:43,994 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sliceTimingCorr, wf_laminar_fMRI_func_pRF.concatenateFunc): No edge data
# 221202-14:02:43,995 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sliceTimingCorr, wf_laminar_fMRI_func_pRF.concatenateFunc): new edge data: {'connect': [('timecorrected_files', 'in_files')]}

# %% [markdown]
# #### Get mean functional volume

# %%
mean_vol = True                 # (a boolean) register to mean volume
save_mats = False               # (a boolean) save transformation parameters

# %%
meanFunc = Node(MCFLIRT(mean_vol = mean_vol, save_mats=save_mats), 
                    name='meanFunc')
# Out:
# 221202-14:02:44,24 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI

# %%
wf.connect([(concatenateFunc, meanFunc,[('merged_file', 'in_file')])])
# Out:
# 221202-14:02:44,38 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.concatenateFunc, wf_laminar_fMRI_func_pRF.meanFunc): No edge data
# 221202-14:02:44,39 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.concatenateFunc, wf_laminar_fMRI_func_pRF.meanFunc): new edge data: {'connect': [('merged_file', 'in_file')]}

# %%
MCFLIRT.help()
# Out:
# Wraps the executable command ``mcflirt``.
#
# FSL MCFLIRT wrapper for within-modality motion correction
#
# For complete details, see the `MCFLIRT Documentation.
# <https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/MCFLIRT>`_
#
# Examples
# --------
# >>> from nipype.interfaces import fsl
# >>> mcflt = fsl.MCFLIRT()
# >>> mcflt.inputs.in_file = 'functional.nii'
# >>> mcflt.inputs.cost = 'mutualinfo'
# >>> mcflt.inputs.out_file = 'moco.nii'
# >>> mcflt.cmdline
# 'mcflirt -in functional.nii -cost mutualinfo -out moco.nii'
# >>> res = mcflt.run()  # doctest: +SKIP
#
# Inputs::
#
#         [Mandatory]
#         in_file: (a pathlike object or string representing an existing file)
#                 timeseries to motion-correct
#                 argument: ``-in %s``, position: 0
#
#         [Optional]
#         out_file: (a pathlike object or string representing a file)
#                 file to write
#                 argument: ``-out %s``
#         cost: ('mutualinfo' or 'woods' or 'corratio' or 'normcorr' or
#                   'normmi' or 'leastsquares')
#                 cost function to optimize
#                 argument: ``-cost %s``
#         bins: (an integer)
#                 number of histogram bins
#                 argument: ``-bins %d``
#         dof: (an integer)
#                 degrees of freedom for the transformation
#                 argument: ``-dof %d``
#         ref_vol: (an integer)
#                 volume to align frames to
#                 argument: ``-refvol %d``
#         scaling: (a float)
#                 scaling factor to use
#                 argument: ``-scaling %.2f``
#         smooth: (a float)
#                 smoothing factor for the cost function
#                 argument: ``-smooth %.2f``
#         rotation: (an integer)
#                 scaling factor for rotation tolerances
#                 argument: ``-rotation %d``
#         stages: (an integer)
#                 stages (if 4, perform final search with sinc interpolation
#                 argument: ``-stages %d``
#         init: (a pathlike object or string representing an existing file)
#                 inital transformation matrix
#                 argument: ``-init %s``
#         interpolation: ('spline' or 'nn' or 'sinc')
#                 interpolation method for transformation
#                 argument: ``-%s_final``
#         use_gradient: (a boolean)
#                 run search on gradient images
#                 argument: ``-gdt``
#         use_contour: (a boolean)
#                 run search on contour images
#                 argument: ``-edge``
#         mean_vol: (a boolean)
#                 register to mean volume
#                 argument: ``-meanvol``
#         stats_imgs: (a boolean)
#                 produce variance and std. dev. images
#                 argument: ``-stats``
#         save_mats: (a boolean)
#                 save transformation matrices
#                 argument: ``-mats``
#         save_plots: (a boolean)
#                 save transformation parameters
#                 argument: ``-plots``
#         save_rms: (a boolean)
#                 save rms displacement parameters
#                 argument: ``-rmsabs -rmsrel``
#         ref_file: (a pathlike object or string representing an existing file)
#                 target image for motion correction
#                 argument: ``-reffile %s``
#         output_type: ('NIFTI' or 'NIFTI_PAIR' or 'NIFTI_GZ' or
#                   'NIFTI_PAIR_GZ')
#                 FSL output type
#         args: (a string)
#                 Additional parameters to the command
#                 argument: ``%s``
#         environ: (a dictionary with keys which are a bytes or None or a value
#                   of class 'str' and with values which are a bytes or None or a
#                   value of class 'str', nipype default value: {})
#                 Environment variables
#
# Outputs::
#
#         out_file: (a pathlike object or string representing an existing file)
#                 motion-corrected timeseries
#         variance_img: (a pathlike object or string representing an existing
#                   file)
#                 variance image
#         std_img: (a pathlike object or string representing an existing file)
#                 standard deviation image
#         mean_img: (a pathlike object or string representing an existing file)
#                 mean timeseries image (if mean_vol=True)
#         par_file: (a pathlike object or string representing an existing file)
#                 text-file with motion parameters
#         mat_file: (a list of items which are a pathlike object or string
#                   representing an existing file)
#                 transformation matrices
#         rms_files: (a list of items which are a pathlike object or string
#                   representing an existing file)
#                 absolute and relative displacement parameters
#
# References:
# -----------
# None

# %% [markdown]
# #### Make functional brain mask for coregistration
# Note: this doesn't necessarily work well for all subjects. Therefore, this mask must be corrected manually. When the manual edits flag is true, the corrected binarized image is expected to be saved in the manual edits subject folder. Editing is done by loading the output of this node as a segmentation in ITKSNAP and then saving as a nifti file named brainMask.nii in the manual edits folder.

# %%
thresh = 350

dilate = 3 # voxels
erode = 4

# %%
binarizeMeanFunc = Node(Binarize(min=thresh, dilate=dilate, erode=erode),name='binarizeMeanFunc')

# %%
wf.connect([(meanFunc,binarizeMeanFunc,[('mean_img','in_file')])])
# Out:
# 221202-14:02:44,99 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.meanFunc, wf_laminar_fMRI_func_pRF.binarizeMeanFunc): No edge data
# 221202-14:02:44,100 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.meanFunc, wf_laminar_fMRI_func_pRF.binarizeMeanFunc): new edge data: {'connect': [('mean_img', 'in_file')]}

# %% [markdown]
# #### Coregister structural image to mean functional (FLIRT)

# %%
out_matrix_file = 'struct2func.mat'     # (a pathlike object or string representing a file)
                                        # output affine matrix in 4x4 asciii format
apply_xfm = True                        # (a boolean)
                                        # apply transformation supplied by in_matrix_file or uses_qform to use
                                        # the affine matrix stored in the reference header
coarse_search = 4
fine_search = 2

# %%
if coregister and coreg_method == 'flirt':
    coreg = Node(FLIRT(),name='coreg')
    
    # out_matrix_file=out_matrix_file, coarse_search=coarse_search, fine_search=fine_search

# %%
if coregister and coreg_method == 'flirt':
    wf.connect([(convertT1ToNii, coreg,[('out_file', 'in_file')])])        
    #wf.connect([(convertT1ToNii, coreg,[('out_file', 'reference')])])   
    wf.connect([(meanFunc, coreg,[('mean_img', 'reference')])])  
    
    if manual_edits:
        wf.connect([(datasourceManualEdits, coreg,[('coreg_itksnap_struct2func_txt', 'in_matrix_file')])])
        coreg.inputs.apply_xfm = apply_xfm

# %%
FLIRT.help()
# Out:
# Wraps the executable command ``flirt``.
#
# FSL FLIRT wrapper for coregistration
#
# For complete details, see the `FLIRT Documentation.
# <https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FLIRT>`_
#
# To print out the command line help, use:
#     fsl.FLIRT().inputs_help()
#
# Examples
# --------
# >>> from nipype.interfaces import fsl
# >>> from nipype.testing import example_data
# >>> flt = fsl.FLIRT(bins=640, cost_func='mutualinfo')
# >>> flt.inputs.in_file = 'structural.nii'
# >>> flt.inputs.reference = 'mni.nii'
# >>> flt.inputs.output_type = "NIFTI_GZ"
# >>> flt.cmdline # doctest: +ELLIPSIS
# 'flirt -in structural.nii -ref mni.nii -out structural_flirt.nii.gz -omat structural_flirt.mat -bins 640 -searchcost mutualinfo'
# >>> res = flt.run() #doctest: +SKIP
#
# Inputs::
#
#         [Mandatory]
#         in_file: (a pathlike object or string representing an existing file)
#                 input file
#                 argument: ``-in %s``, position: 0
#         reference: (a pathlike object or string representing an existing
#                   file)
#                 reference file
#                 argument: ``-ref %s``, position: 1
#
#         [Optional]
#         out_file: (a pathlike object or string representing a file)
#                 registered output file
#                 argument: ``-out %s``, position: 2
#         out_matrix_file: (a pathlike object or string representing a file)
#                 output affine matrix in 4x4 asciii format
#                 argument: ``-omat %s``, position: 3
#         out_log: (a pathlike object or string representing a file)
#                 output log
#                 requires: save_log
#         in_matrix_file: (a pathlike object or string representing a file)
#                 input 4x4 affine matrix
#                 argument: ``-init %s``
#         apply_xfm: (a boolean)
#                 apply transformation supplied by in_matrix_file or uses_qform to use
#                 the affine matrix stored in the reference header
#                 argument: ``-applyxfm``
#         apply_isoxfm: (a float)
#                 as applyxfm but forces isotropic resampling
#                 argument: ``-applyisoxfm %f``
#                 mutually_exclusive: apply_xfm
#         datatype: ('char' or 'short' or 'int' or 'float' or 'double')
#                 force output data type
#                 argument: ``-datatype %s``
#         cost: ('mutualinfo' or 'corratio' or 'normcorr' or 'normmi' or
#                   'leastsq' or 'labeldiff' or 'bbr')
#                 cost function
#                 argument: ``-cost %s``
#         cost_func: ('mutualinfo' or 'corratio' or 'normcorr' or 'normmi' or
#                   'leastsq' or 'labeldiff' or 'bbr')
#                 cost function
#                 argument: ``-searchcost %s``
#         uses_qform: (a boolean)
#                 initialize using sform or qform
#                 argument: ``-usesqform``
#         display_init: (a boolean)
#                 display initial matrix
#                 argument: ``-displayinit``
#         angle_rep: ('quaternion' or 'euler')
#                 representation of rotation angles
#                 argument: ``-anglerep %s``
#         interp: ('trilinear' or 'nearestneighbour' or 'sinc' or 'spline')
#                 final interpolation method used in reslicing
#                 argument: ``-interp %s``
#         sinc_width: (an integer)
#                 full-width in voxels
#                 argument: ``-sincwidth %d``
#         sinc_window: ('rectangular' or 'hanning' or 'blackman')
#                 sinc window
#                 argument: ``-sincwindow %s``
#         bins: (an integer)
#                 number of histogram bins
#                 argument: ``-bins %d``
#         dof: (an integer)
#                 number of transform degrees of freedom
#                 argument: ``-dof %d``
#         no_resample: (a boolean)
#                 do not change input sampling
#                 argument: ``-noresample``
#         force_scaling: (a boolean)
#                 force rescaling even for low-res images
#                 argument: ``-forcescaling``
#         min_sampling: (a float)
#                 set minimum voxel dimension for sampling
#                 argument: ``-minsampling %f``
#         padding_size: (an integer)
#                 for applyxfm: interpolates outside image by size
#                 argument: ``-paddingsize %d``
#         searchr_x: (a list of from 2 to 2 items which are an integer)
#                 search angles along x-axis, in degrees
#                 argument: ``-searchrx %s``
#         searchr_y: (a list of from 2 to 2 items which are an integer)
#                 search angles along y-axis, in degrees
#                 argument: ``-searchry %s``
#         searchr_z: (a list of from 2 to 2 items which are an integer)
#                 search angles along z-axis, in degrees
#                 argument: ``-searchrz %s``
#         no_search: (a boolean)
#                 set all angular searches to ranges 0 to 0
#                 argument: ``-nosearch``
#         coarse_search: (an integer)
#                 coarse search delta angle
#                 argument: ``-coarsesearch %d``
#         fine_search: (an integer)
#                 fine search delta angle
#                 argument: ``-finesearch %d``
#         schedule: (a pathlike object or string representing an existing file)
#                 replaces default schedule
#                 argument: ``-schedule %s``
#         ref_weight: (a pathlike object or string representing an existing
#                   file)
#                 File for reference weighting volume
#                 argument: ``-refweight %s``
#         in_weight: (a pathlike object or string representing an existing
#                   file)
#                 File for input weighting volume
#                 argument: ``-inweight %s``
#         no_clamp: (a boolean)
#                 do not use intensity clamping
#                 argument: ``-noclamp``
#         no_resample_blur: (a boolean)
#                 do not use blurring on downsampling
#                 argument: ``-noresampblur``
#         rigid2D: (a boolean)
#                 use 2D rigid body mode - ignores dof
#                 argument: ``-2D``
#         save_log: (a boolean)
#                 save to log file
#         verbose: (an integer)
#                 verbose mode, 0 is least
#                 argument: ``-verbose %d``
#         bgvalue: (a float)
#                 use specified background value for points outside FOV
#                 argument: ``-setbackground %f``
#         wm_seg: (a pathlike object or string representing a file)
#                 white matter segmentation volume needed by BBR cost function
#                 argument: ``-wmseg %s``
#         wmcoords: (a pathlike object or string representing a file)
#                 white matter boundary coordinates for BBR cost function
#                 argument: ``-wmcoords %s``
#         wmnorms: (a pathlike object or string representing a file)
#                 white matter boundary normals for BBR cost function
#                 argument: ``-wmnorms %s``
#         fieldmap: (a pathlike object or string representing a file)
#                 fieldmap image in rads/s - must be already registered to the
#                 reference image
#                 argument: ``-fieldmap %s``
#         fieldmapmask: (a pathlike object or string representing a file)
#                 mask for fieldmap image
#                 argument: ``-fieldmapmask %s``
#         pedir: (an integer)
#                 phase encode direction of EPI - 1/2/3=x/y/z & -1/-2/-3=-x/-y/-z
#                 argument: ``-pedir %d``
#         echospacing: (a float)
#                 value of EPI echo spacing - units of seconds
#                 argument: ``-echospacing %f``
#         bbrtype: ('signed' or 'global_abs' or 'local_abs')
#                 type of bbr cost function: signed [default], global_abs, local_abs
#                 argument: ``-bbrtype %s``
#         bbrslope: (a float)
#                 value of bbr slope
#                 argument: ``-bbrslope %f``
#         output_type: ('NIFTI' or 'NIFTI_PAIR' or 'NIFTI_GZ' or
#                   'NIFTI_PAIR_GZ')
#                 FSL output type
#         args: (a string)
#                 Additional parameters to the command
#                 argument: ``%s``
#         environ: (a dictionary with keys which are a bytes or None or a value
#                   of class 'str' and with values which are a bytes or None or a
#                   value of class 'str', nipype default value: {})
#                 Environment variables
#
# Outputs::
#
#         out_file: (a pathlike object or string representing an existing file)
#                 path/name of registered file (if generated)
#         out_matrix_file: (a pathlike object or string representing an
#                   existing file)
#                 path/name of calculated affine transform (if generated)
#         out_log: (a pathlike object or string representing a file)
#                 path/name of output log (if generated)
#
# References:
# -----------
# None

# %% [markdown]
# #### Coregister structural image to mean functional (FS)
#
# not done!

# %%
# contrast_type = 't2'

# %%
# if coreg_method == 'freesurfer':
#     #coreg = Node(MRICoreg(),name='coreg')
    
#     coreg = Node(BBRegister(contrast_type=contrast_type),name='coreg')

# %%
# if coreg_method == 'freesurfer':
#     wf.connect([(convertT1ToNii, coreg,[('out_file', 'source_file')])])
#     if manual_edits:
#         wf.connect([(datasourceManualEdits, coreg,[('coreg_itksnap_txt','init_reg_file')])])
            
#     wf.connect([(meanFunc, coreg,[('mean_img', 'source_file')])])

# %%
# BBRegister.help()

# %% [markdown]
# #### Coregister structural image to mean functional (apply manual ITK-snap correction)
# https://layerfmri.com/2019/02/11/high-quality-registration/
#
#
# ##### Mandatory inputs
# input_image (a pathlike object or string representing an existing file) – Image to apply transformation to (generally a coregistered functional). Maps to a command-line argument: --input %s.
#
# reference_image (a pathlike object or string representing an existing file) – Reference image space that you wish to warp INTO. Maps to a command-line argument: --reference-image %s.
#
# transforms (a list of items which are a pathlike object or string representing an existing file or ‘identity’) – Transform files: will be applied in reverse order. For example, the last specified transform will be applied first. Maps to a command-line argument: %s.
#
# ##### Optional inputs
# args (a string) – Additional parameters to the command. Maps to a command-line argument: %s.
#
# default_value (a float) – Maps to a command-line argument: --default-value %g. (Nipype default value: 0.0)
#
# dimension (2 or 3 or 4) – This option forces the image to be treated as a specified-dimensional image. If not specified, antsWarp tries to infer the dimensionality from the input image. Maps to a command-line argument: --dimensionality %d.
#
# environ (a dictionary with keys which are a bytes or None or a value of class ‘str’ and with values which are a bytes or None or a value of class ‘str’) – Environment variables. (Nipype default value: {})
#
# float (a boolean) – Use float instead of double for computations. Maps to a command-line argument: --float %d. (Nipype default value: False)
#
# input_image_type (0 or 1 or 2 or 3) – Option specifying the input image type of scalar (default), vector, tensor, or time series. Maps to a command-line argument: --input-image-type %d.
#
# interpolation (‘Linear’ or ‘NearestNeighbor’ or ‘CosineWindowedSinc’ or ‘WelchWindowedSinc’ or ‘HammingWindowedSinc’ or ‘LanczosWindowedSinc’ or ‘MultiLabel’ or ‘Gaussian’ or ‘BSpline’) – Maps to a command-line argument: %s. (Nipype default value: Linear)
#
# interpolation_parameters (a tuple of the form: (an integer) or a tuple of the form: (a float, a float))
#
# invert_transform_flags (a list of items which are a boolean)
#
# num_threads (an integer) – Number of ITK threads to use. (Nipype default value: 1)
#
# out_postfix (a string) – Postfix that is appended to all output files (default = _trans). (Nipype default value: _trans)
#
# output_image (a string) – Output file name. Maps to a command-line argument: --output %s.
#
# print_out_composite_warp_file (a boolean) – Output a composite warp file instead of a transformed image. Requires inputs: output_image.

# %%
#antsApplyTransforms --interpolation BSpline[5] -d 3 -i MP2RAGE.nii -r EPI.nii -t initial_matrix.txt -o registered_applied.nii

# %%
interpolation = 'BSpline'
dimension = 3

# %%
if coregister and coreg_method == 'itk-snap':
    coreg = Node(ApplyTransforms(interpolation=interpolation,
                                dimension=dimension), name='coreg')

# %%
if coregister and coreg_method == 'itk-snap':
    wf.connect([(convertT1ToNii, coreg,[('out_file', 'input_image')])])        
    wf.connect([(meanFunc, coreg,[('mean_img', 'reference_image')])])  

    wf.connect([(datasourceManualEdits, coreg,[('coreg_itksnap_struct2func_txt', 'transforms')])])

# %% [markdown]
# #### Coregister mean functional to anatomical image (ANTs)
# https://layerfmri.com/2019/02/11/high-quality-registration/
#
# antsRegistration \
# --verbose 1 \
# --dimensionality 3 \
# --float 1 \
# --output [registered_,registered_Warped.nii.gz,registered_InverseWarped.nii.gz] \
# --interpolation Linear \
# --use-histogram-matching 0 \
# --winsorize-image-intensities [0.005,0.995] \
# --initial-moving-transform initial_matrix.txt \
# --transform Rigid[0.05] \
# --metric CC[static_image.nii,moving_image.nii,0.7,32,Regular,0.1] \
# --convergence [1000x500,1e-6,10] \
# --shrink-factors 2x1 \
# --smoothing-sigmas 1x0vox \
# --transform Affine[0.1] \
# --metric MI[static_image.nii,moving_image.nii,0.7,32,Regular,0.1] \
# --convergence [1000x500,1e-6,10] \
# --shrink-factors 2x1 \
# --smoothing-sigmas 1x0vox \
# --transform SyN[0.1,2,0] \
# --metric CC[static_image.nii,moving_image.nii,1,2] \
# --convergence [500x100,1e-6,10] \
# --shrink-factors 2x1 \
# --smoothing-sigmas 1x0vox \
# -x mask.nii
#
#
# See also: https://github.com/ANTsX/ANTs/wiki/Anatomy-of-an-antsRegistration-call
#
# about masking: https://github.com/ANTsX/ANTs/issues/483

# %%
verbose = True                          # (a boolean, nipype default value: False)
                                        # argument: ``-v``
    
dimension = 3                           # dimension: (3 or 2, nipype default value: 3)
                                        # image dimension (2 or 3)
                                        # argument: ``--dimensionality %d``
        
float = True                            # (a boolean)
                                        # Use float instead of double for computations.
                                        # argument: ``--float %d``
        
output_transform_prefix = 'registered_' # (a string, nipype default value: transform)
                                        # argument: ``%s``
    
output_warped_image = 'registered_Warped.nii.gz'              
                                        # (a boolean or a pathlike object or string
                                        # representing a file)
    
output_inverse_warped_image = 'registered_InverseWarped.nii.gz'       
                                        # (a boolean or a pathlike object or
                                        # string representing a file)
                                        # requires: output_warped_image
        
interpolation = 'Linear'                # ('Linear' or 'NearestNeighbor' or 'CosineWindowedSinc'
                                        # or 'WelchWindowedSinc' or 'HammingWindowedSinc' or
                                        # 'LanczosWindowedSinc' or 'BSpline' or 'MultiLabel' or 'Gaussian',
                                        # nipype default value: Linear)
                                        # argument: ``%s``   
                
use_histogram_matching = False          #  (a boolean or a list of items which are a
                                        # boolean, nipype default value: True)
                                        # Histogram match the images before registration. 
        
winsorize_lower_quantile = 0.005        # (0.0 <= a floating point number <= 1.0,
                                        # nipype default value: 0.0)
                                        # The Lower quantile to clip image ranges
                                        # argument: ``%s``
            
winsorize_upper_quantile = 0.995        # (0.0 <= a floating point number <= 1.0,
                                        # nipype default value: 1.0)
                                        # The Upper quantile to clip image ranges
                                        # argument: ``%s``
            
#initial_moving_transform = 'initial_matrix.txt'   # (a list of items which are an existing file
                                        # name)
                                        # A transform or a list of transforms that should be appliedbefore the
                                        # registration begins. Note that, when a list is given,the
                                        # transformations are applied in reverse order.
                                        # argument: ``%s``
                                        # mutually_exclusive: initial_moving_transform_com
                        
transforms = ['Rigid','Affine','SyN']   # (a list of items which are 'Rigid' or 'Affine' or
                                        # 'CompositeAffine' or 'Similarity' or 'Translation' or 'BSpline' or
                                        # 'GaussianDisplacementField' or 'TimeVaryingVelocityField' or
                                        # 'TimeVaryingBSplineVelocityField' or 'SyN' or 'BSplineSyN' or
                                        # 'Exponential' or 'BSplineExponential')
                                        # argument: ``%s``
                    
transform_parameters = [(0.1,), (0.1,), (0.1, 3.0, 0.0)]        
                                        # (a list of items which are a tuple of the form:
                                        # (a float) or a tuple of the form: (a float, a float, a float) or a
                                        # tuple of the form: (a float, an integer (int or long), an integer
                                        # (int or long), an integer (int or long)) or a tuple of the form:
                                        # (a float, an integer (int or long), a float, a float, a float, a
                                        # float) or a tuple of the form: (a float, a float, a float, an
                                        # integer (int or long)) or a tuple of the form: (a float, an
                                        # integer (int or long), an integer (int or long), an integer (int
                                        # or long), an integer (int or long)))
                                
metric = ['MI', 'MI', 'CC']             # (a list of items which are 'CC' or 'MeanSquares' or 'Demons'
                                        # or 'GC' or 'MI' or 'Mattes' or a list of items which are 'CC' or
                                        # 'MeanSquares' or 'Demons' or 'GC' or 'MI' or 'Mattes')
                                        # the metric(s) to use for each stage. Note that multiple metrics per
                                        # stage are not supported in ANTS 1.9.1 and earlier.
                
metric_weight = [1.0,1.0,1.0]           # (a list of items which are a float or a list of items
                                        # which are a float, nipype default value: [1.0])
                                        # the metric weight(s) for each stage. The weights must sum to 1 per
                                        # stage.
                                        # requires: metric
                
radius_or_number_of_bins = [32,32,4]    # (a list of items which are an integer (int
                                        # or long) or a list of items which are an integer (int or long),
                                        # nipype default value: [5])
                                        # the number of bins in each stage for the MI and Mattes metric, the
                                        # radius for other metrics
                                        # requires: metric_weight
                    
sampling_strategy = ['Regular','Regular','None']              
                                        # (a list of items which are 'None' or 'Regular' or
                                        # 'Random' or None or a list of items which are 'None' or 'Regular'
                                        # or 'Random' or None)
                                        # the metric sampling strategy (strategies) for each stage
                                        # requires: metric_weight
                
sampling_percentage = [0.25, 0.25, None]         
                                        # (a list of items which are 0.0 <= a floating
                                        # point number <= 1.0 or None or a list of items which are 0.0 <= a
                                        # floating point number <= 1.0 or None)
                                        # the metric sampling percentage(s) to use for each stage
                                        # requires: sampling_strategy
                
convergence_threshold = [1e-6,1e-6,1e-6]# (a list of at least 1 items which are a float,
                                        # nipype default value: [1e-06])
                                        # requires: number_of_iterations
        
convergence_window_size = [10,10,10]    # (a list of at least 1 items which are an
                                        # integer (int or long), nipype default value: [10])
                                        # requires: convergence_threshold
        
number_of_iterations = [[1000,500,250,100], [1000,500,250,100],[100,70,50,20]]       
                                        # (a list of items which are a list of items
                                        # which are an integer (int or long))                
                                        
shrink_factors = [[8,4,2,1], [8,4,2,1], [8,4,2,1]]  
                                        # (a list of items which are a list of items which are
                                        # an integer (int or long))
    
smoothing_sigmas = [[3.0,2.0,1.0,0.0], [3.0,2.0,1.0,0.0], [3.0,2.0,1.0,0.0]]
                                        # (a list of items which are a list of items which
                                        # are a float)

# %%
if coregister and coreg_method == 'antsRegistration':
    coreg = Node(Registration(verbose=verbose,
                              dimension=dimension,
                              float=float,
                              output_transform_prefix=output_transform_prefix,
                              output_warped_image=output_warped_image,
                              output_inverse_warped_image=output_inverse_warped_image,
                              interpolation=interpolation, 
                              use_histogram_matching=use_histogram_matching,
                              winsorize_lower_quantile=winsorize_lower_quantile,
                              winsorize_upper_quantile=winsorize_upper_quantile, 
                              transforms=transforms, 
                              transform_parameters=transform_parameters,
                              metric=metric, 
                              metric_weight=metric_weight, 
                              radius_or_number_of_bins=radius_or_number_of_bins,
                              sampling_strategy=sampling_strategy, 
                              sampling_percentage=sampling_percentage,
                              convergence_threshold=convergence_threshold, 
                              convergence_window_size=convergence_window_size,
                              number_of_iterations=number_of_iterations, 
                              shrink_factors=shrink_factors, 
                              smoothing_sigmas=smoothing_sigmas),
                 name='coreg')

# %%
if coregister and coreg_method == 'antsRegistration':
    if coreg_dir == 'func2struct':
        # when moving func 2 struct
        wf.connect([(datasource, coreg,[('UNI', 'fixed_image')])])    
        wf.connect([(meanFunc, coreg,[('mean_img', 'moving_image')])])
        wf.connect([(datasourceManualEdits, coreg,[('coreg_itksnap_func2struct_txt', 'initial_moving_transform')])])    
        #wf.connect([(datasource, coreg,[('brainmask', 'fixed_image_masks')])])
        wf.connect([(datasourceManualEdits, coreg,[('manual_midoccmask', 'fixed_image_masks')])])
        
    elif coreg_dir == 'struct2func':
        # when moving struct 2 func:
        wf.connect([(meanFunc, coreg,[('mean_img', 'fixed_image')])]) 
        wf.connect([(datasource, coreg,[('UNI', 'moving_image')])])
        wf.connect([(datasourceManualEdits, coreg,[('coreg_itksnap_struct2func_txt', 'initial_moving_transform')])])
        #wf.connect([(datasource, coreg,[('brainmask', 'moving_image_masks')])])
        wf.connect([(datasourceManualEdits, coreg,[('manual_midoccmask', 'moving_image_masks')])])
# Out:
# 221202-14:02:47,292 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasource, wf_laminar_fMRI_func_pRF.coreg): No edge data
# 221202-14:02:47,293 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasource, wf_laminar_fMRI_func_pRF.coreg): new edge data: {'connect': [('UNI', 'fixed_image')]}
# 221202-14:02:47,294 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.meanFunc, wf_laminar_fMRI_func_pRF.coreg): No edge data
# 221202-14:02:47,295 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.meanFunc, wf_laminar_fMRI_func_pRF.coreg): new edge data: {'connect': [('mean_img', 'moving_image')]}
# 221202-14:02:47,295 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasourceManualEdits, wf_laminar_fMRI_func_pRF.coreg): No edge data
# 221202-14:02:47,296 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasourceManualEdits, wf_laminar_fMRI_func_pRF.coreg): new edge data: {'connect': [('coreg_itksnap_func2struct_txt', 'initial_moving_transform')]}
# 221202-14:02:47,297 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasourceManualEdits, wf_laminar_fMRI_func_pRF.coreg): Edge data exists: {'connect': [('coreg_itksnap_func2struct_txt', 'initial_moving_transform')]}
# 221202-14:02:47,297 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasourceManualEdits, wf_laminar_fMRI_func_pRF.coreg): new edge data: {'connect': [('coreg_itksnap_func2struct_txt', 'initial_moving_transform'), ('manual_midoccmask', 'fixed_image_masks')]}

# %%
Registration.help()
# Out:
# Wraps the executable command ``antsRegistration``.
#
# ANTs Registration command for registration of images
#
# `antsRegistration <http://stnava.github.io/ANTs/>`_ registers a ``moving_image`` to a ``fixed_image``,
# using a predefined (sequence of) cost function(s) and transformation operations.
# The cost function is defined using one or more 'metrics', specifically
# local cross-correlation (``CC``), Mean Squares (``MeanSquares``), Demons (``Demons``),
# global correlation (``GC``), or Mutual Information (``Mattes`` or ``MI``).
#
# ANTS can use both linear (``Translation``, ``Rigid``, ``Affine``, ``CompositeAffine``,
# or ``Translation``) and non-linear transformations (``BSpline``, ``GaussianDisplacementField``,
# ``TimeVaryingVelocityField``, ``TimeVaryingBSplineVelocityField``, ``SyN``, ``BSplineSyN``,
# ``Exponential``, or ``BSplineExponential``). Usually, registration is done in multiple
# *stages*. For example first an Affine, then a Rigid, and ultimately a non-linear
# (Syn)-transformation.
#
# antsRegistration can be initialized using one ore more transforms from moving_image
# to fixed_image with the ``initial_moving_transform``-input. For example, when you
# already have a warpfield that corrects for geometrical distortions in an EPI (functional) image,
# that you want to apply before an Affine registration to a structural image.
# You could put this transform into 'intial_moving_transform'.
#
# The Registration-interface can output the resulting transform(s) that map moving_image to
# fixed_image in a single file as a ``composite_transform`` (if ``write_composite_transform``
# is set to ``True``), or a list of transforms as ``forwards_transforms``. It can also output
# inverse transforms (from ``fixed_image`` to ``moving_image``) in a similar fashion using
# ``inverse_composite_transform``. Note that the order of ``forward_transforms`` is in 'natural'
# order: the first element should be applied first, the last element should be applied last.
#
# Note, however, that ANTS tools always apply lists of transformations in reverse order (the last
# transformation in the list is applied first). Therefore, if the output forward_transforms
# is a list, one can not directly feed it into, for example, ``ants.ApplyTransforms``. To
# make ``ants.ApplyTransforms`` apply the transformations in the same order as ``ants.Registration``,
# you have to provide the list of transformations in reverse order from ``forward_transforms``.
# ``reverse_forward_transforms`` outputs ``forward_transforms`` in reverse order and can be used for
# this purpose. Note also that, because ``composite_transform`` is always a single file, this
# output is preferred for  most use-cases.
#
# More information can be found in the `ANTS
# manual <https://sourceforge.net/projects/advants/files/Documentation/ants.pdf/download>`_.
#
# See below for some useful examples.
#
# Examples
# --------
#
# Set up a Registration node with some default settings. This Node registers
# 'fixed1.nii' to 'moving1.nii' by first fitting a linear 'Affine' transformation, and
# then a non-linear 'SyN' transformation, both using the Mutual Information-cost
# metric.
#
# The registration is initialized by first applying the (linear) transform
# trans.mat.
#
# >>> import copy, pprint
# >>> from nipype.interfaces.ants import Registration
# >>> reg = Registration()
# >>> reg.inputs.fixed_image = 'fixed1.nii'
# >>> reg.inputs.moving_image = 'moving1.nii'
# >>> reg.inputs.output_transform_prefix = "output_"
# >>> reg.inputs.initial_moving_transform = 'trans.mat'
# >>> reg.inputs.transforms = ['Affine', 'SyN']
# >>> reg.inputs.transform_parameters = [(2.0,), (0.25, 3.0, 0.0)]
# >>> reg.inputs.number_of_iterations = [[1500, 200], [100, 50, 30]]
# >>> reg.inputs.dimension = 3
# >>> reg.inputs.write_composite_transform = True
# >>> reg.inputs.collapse_output_transforms = False
# >>> reg.inputs.initialize_transforms_per_stage = False
# >>> reg.inputs.metric = ['Mattes']*2
# >>> reg.inputs.metric_weight = [1]*2 # Default (value ignored currently by ANTs)
# >>> reg.inputs.radius_or_number_of_bins = [32]*2
# >>> reg.inputs.sampling_strategy = ['Random', None]
# >>> reg.inputs.sampling_percentage = [0.05, None]
# >>> reg.inputs.convergence_threshold = [1.e-8, 1.e-9]
# >>> reg.inputs.convergence_window_size = [20]*2
# >>> reg.inputs.smoothing_sigmas = [[1,0], [2,1,0]]
# >>> reg.inputs.sigma_units = ['vox'] * 2
# >>> reg.inputs.shrink_factors = [[2,1], [3,2,1]]
# >>> reg.inputs.use_estimate_learning_rate_once = [True, True]
# >>> reg.inputs.use_histogram_matching = [True, True] # This is the default
# >>> reg.inputs.output_warped_image = 'output_warped_image.nii.gz'
# >>> reg.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --initial-moving-transform [ trans.mat, 0 ] --initialize-transforms-per-stage 0 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1'
# >>> reg.run()  # doctest: +SKIP
#
# Same as reg1, but first invert the initial transform ('trans.mat') before applying it.
#
# >>> reg.inputs.invert_initial_moving_transform = True
# >>> reg1 = copy.deepcopy(reg)
# >>> reg1.inputs.winsorize_lower_quantile = 0.025
# >>> reg1.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 0 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.025, 1.0 ]  --write-composite-transform 1'
# >>> reg1.run()  # doctest: +SKIP
#
# Clip extremely high intensity data points using winsorize_upper_quantile. All data points
# higher than the 0.975 quantile are set to the value of the 0.975 quantile.
#
# >>> reg2 = copy.deepcopy(reg)
# >>> reg2.inputs.winsorize_upper_quantile = 0.975
# >>> reg2.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 0 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 0.975 ]  --write-composite-transform 1'
#
# Clip extremely low intensity data points using winsorize_lower_quantile. All data points
# lower than the 0.025 quantile are set to the original value at the 0.025 quantile.
#
#
# >>> reg3 = copy.deepcopy(reg)
# >>> reg3.inputs.winsorize_lower_quantile = 0.025
# >>> reg3.inputs.winsorize_upper_quantile = 0.975
# >>> reg3.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 0 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.025, 0.975 ]  --write-composite-transform 1'
#
# Use float instead of double for computations (saves memory usage)
#
# >>> reg3a = copy.deepcopy(reg)
# >>> reg3a.inputs.float = True
# >>> reg3a.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --float 1 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 0 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1'
#
# Force to use double instead of float for computations (more precision and memory usage).
#
# >>> reg3b = copy.deepcopy(reg)
# >>> reg3b.inputs.float = False
# >>> reg3b.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --float 0 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 0 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1'
#
# 'collapse_output_transforms' can be used to put all transformation in a single 'composite_transform'-
# file. Note that forward_transforms will now be an empty list.
#
# >>> # Test collapse transforms flag
# >>> reg4 = copy.deepcopy(reg)
# >>> reg4.inputs.save_state = 'trans.mat'
# >>> reg4.inputs.restore_state = 'trans.mat'
# >>> reg4.inputs.initialize_transforms_per_stage = True
# >>> reg4.inputs.collapse_output_transforms = True
# >>> outputs = reg4._list_outputs()
# >>> pprint.pprint(outputs)  # doctest: +ELLIPSIS,
# {'composite_transform': '...data/output_Composite.h5',
#  'elapsed_time': <undefined>,
#  'forward_invert_flags': [],
#  'forward_transforms': [],
#  'inverse_composite_transform': '...data/output_InverseComposite.h5',
#  'inverse_warped_image': <undefined>,
#  'metric_value': <undefined>,
#  'reverse_forward_invert_flags': [],
#  'reverse_forward_transforms': [],
#  'reverse_invert_flags': [],
#  'reverse_transforms': [],
#  'save_state': '...data/trans.mat',
#  'warped_image': '...data/output_warped_image.nii.gz'}
# >>> reg4.cmdline
# 'antsRegistration --collapse-output-transforms 1 --dimensionality 3 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 1 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --restore-state trans.mat --save-state trans.mat --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1'
#
#
# >>> # Test collapse transforms flag
# >>> reg4b = copy.deepcopy(reg4)
# >>> reg4b.inputs.write_composite_transform = False
# >>> outputs = reg4b._list_outputs()
# >>> pprint.pprint(outputs)  # doctest: +ELLIPSIS,
# {'composite_transform': <undefined>,
#  'elapsed_time': <undefined>,
#  'forward_invert_flags': [False, False],
#  'forward_transforms': ['...data/output_0GenericAffine.mat',
#  '...data/output_1Warp.nii.gz'],
#  'inverse_composite_transform': <undefined>,
#  'inverse_warped_image': <undefined>,
#  'metric_value': <undefined>,
#  'reverse_forward_invert_flags': [False, False],
#  'reverse_forward_transforms': ['...data/output_1Warp.nii.gz',
#  '...data/output_0GenericAffine.mat'],
#  'reverse_invert_flags': [True, False],
#  'reverse_transforms': ['...data/output_0GenericAffine.mat',     '...data/output_1InverseWarp.nii.gz'],
#  'save_state': '...data/trans.mat',
#  'warped_image': '...data/output_warped_image.nii.gz'}
# >>> reg4b.aggregate_outputs()  # doctest: +SKIP
# >>> reg4b.cmdline
# 'antsRegistration --collapse-output-transforms 1 --dimensionality 3 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 1 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --restore-state trans.mat --save-state trans.mat --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 0'
#
# One can use multiple similarity metrics in a single registration stage.The Node below first
# performs a linear registation using only the Mutual Information ('Mattes')-metric.
# In a second stage, it performs a non-linear registration ('Syn') using both a
# Mutual Information and a local cross-correlation ('CC')-metric. Both metrics are weighted
# equally ('metric_weight' is .5 for both). The Mutual Information- metric uses 32 bins.
# The local cross-correlations (correlations between every voxel's neighborhoods) is computed
# with a radius of 4.
#
# >>> # Test multiple metrics per stage
# >>> reg5 = copy.deepcopy(reg)
# >>> reg5.inputs.fixed_image = 'fixed1.nii'
# >>> reg5.inputs.moving_image = 'moving1.nii'
# >>> reg5.inputs.metric = ['Mattes', ['Mattes', 'CC']]
# >>> reg5.inputs.metric_weight = [1, [.5,.5]]
# >>> reg5.inputs.radius_or_number_of_bins = [32, [32, 4] ]
# >>> reg5.inputs.sampling_strategy = ['Random', None] # use default strategy in second stage
# >>> reg5.inputs.sampling_percentage = [0.05, [0.05, 0.10]]
# >>> reg5.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 0 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 0.5, 32, None, 0.05 ] --metric CC[ fixed1.nii, moving1.nii, 0.5, 4, None, 0.1 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1'
#
# ANTS Registration can also use multiple modalities to perform the registration. Here it is assumed
# that fixed1.nii and fixed2.nii are in the same space, and so are moving1.nii and
# moving2.nii. First, a linear registration is performed matching fixed1.nii to moving1.nii,
# then a non-linear registration is performed to match fixed2.nii to moving2.nii, starting from
# the transformation of the first step.
#
# >>> # Test multiple inputS
# >>> reg6 = copy.deepcopy(reg5)
# >>> reg6.inputs.fixed_image = ['fixed1.nii', 'fixed2.nii']
# >>> reg6.inputs.moving_image = ['moving1.nii', 'moving2.nii']
# >>> reg6.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 0 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 0.5, 32, None, 0.05 ] --metric CC[ fixed2.nii, moving2.nii, 0.5, 4, None, 0.1 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1'
#
# Different methods can be used for the interpolation when applying transformations.
#
# >>> # Test Interpolation Parameters (BSpline)
# >>> reg7a = copy.deepcopy(reg)
# >>> reg7a.inputs.interpolation = 'BSpline'
# >>> reg7a.inputs.interpolation_parameters = (3,)
# >>> reg7a.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 0 --interpolation BSpline[ 3 ] --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1'
#
# >>> # Test Interpolation Parameters (MultiLabel/Gaussian)
# >>> reg7b = copy.deepcopy(reg)
# >>> reg7b.inputs.interpolation = 'Gaussian'
# >>> reg7b.inputs.interpolation_parameters = (1.0, 1.0)
# >>> reg7b.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 0 --interpolation Gaussian[ 1.0, 1.0 ] --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1'
#
# BSplineSyN non-linear registration with custom parameters.
#
# >>> # Test Extended Transform Parameters
# >>> reg8 = copy.deepcopy(reg)
# >>> reg8.inputs.transforms = ['Affine', 'BSplineSyN']
# >>> reg8.inputs.transform_parameters = [(2.0,), (0.25, 26, 0, 3)]
# >>> reg8.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 0 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform BSplineSyN[ 0.25, 26, 0, 3 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1'
#
# Mask the fixed image in the second stage of the registration (but not the first).
#
# >>> # Test masking
# >>> reg9 = copy.deepcopy(reg)
# >>> reg9.inputs.fixed_image_masks = ['NULL', 'fixed1.nii']
# >>> reg9.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --initial-moving-transform [ trans.mat, 1 ] --initialize-transforms-per-stage 0 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --masks [ NULL, NULL ] --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --masks [ fixed1.nii, NULL ] --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1'
#
# Here we use both a warpfield and a linear transformation, before registration commences.  Note that
# the first transformation that needs to be applied ('ants_Warp.nii.gz') is last in the list of
# 'initial_moving_transform'.
#
# >>> # Test initialization with multiple transforms matrices (e.g., unwarp and affine transform)
# >>> reg10 = copy.deepcopy(reg)
# >>> reg10.inputs.initial_moving_transform = ['func_to_struct.mat', 'ants_Warp.nii.gz']
# >>> reg10.inputs.invert_initial_moving_transform = [False, False]
# >>> reg10.cmdline
# 'antsRegistration --collapse-output-transforms 0 --dimensionality 3 --initial-moving-transform [ func_to_struct.mat, 0 ] [ ants_Warp.nii.gz, 0 ] --initialize-transforms-per-stage 0 --interpolation Linear --output [ output_, output_warped_image.nii.gz ] --transform Affine[ 2.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32, Random, 0.05 ] --convergence [ 1500x200, 1e-08, 20 ] --smoothing-sigmas 1.0x0.0vox --shrink-factors 2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --transform SyN[ 0.25, 3.0, 0.0 ] --metric Mattes[ fixed1.nii, moving1.nii, 1, 32 ] --convergence [ 100x50x30, 1e-09, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 3x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1'
#
# Inputs::
#
#         [Mandatory]
#         fixed_image: (a list of items which are a pathlike object or string
#                   representing an existing file)
#                 Image to which the moving_image should be transformed(usually a
#                 structural image)
#         moving_image: (a list of items which are a pathlike object or string
#                   representing an existing file)
#                 Image that will be registered to the space of fixed_image. This is
#                 theimage on which the transformations will be applied to
#         metric: (a list of items which are 'CC' or 'MeanSquares' or 'Demons'
#                   or 'GC' or 'MI' or 'Mattes' or a list of items which are 'CC' or
#                   'MeanSquares' or 'Demons' or 'GC' or 'MI' or 'Mattes')
#                 the metric(s) to use for each stage. Note that multiple metrics per
#                 stage are not supported in ANTS 1.9.1 and earlier.
#         metric_weight: (a list of items which are a float or a list of items
#                   which are a float, nipype default value: [1.0])
#                 the metric weight(s) for each stage. The weights must sum to 1 per
#                 stage.
#                 requires: metric
#         transforms: (a list of items which are 'Rigid' or 'Affine' or
#                   'CompositeAffine' or 'Similarity' or 'Translation' or 'BSpline' or
#                   'GaussianDisplacementField' or 'TimeVaryingVelocityField' or
#                   'TimeVaryingBSplineVelocityField' or 'SyN' or 'BSplineSyN' or
#                   'Exponential' or 'BSplineExponential')
#                 argument: ``%s``
#         smoothing_sigmas: (a list of items which are a list of items which
#                   are a float)
#         shrink_factors: (a list of items which are a list of items which are
#                   an integer)
#
#         [Optional]
#         dimension: (3 or 2, nipype default value: 3)
#                 image dimension (2 or 3)
#                 argument: ``--dimensionality %d``
#         fixed_image_mask: (a pathlike object or string representing an
#                   existing file)
#                 Mask used to limit metric sampling region of the fixed imagein all
#                 stages
#                 argument: ``%s``
#                 mutually_exclusive: fixed_image_masks
#         fixed_image_masks: (a list of items which are a pathlike object or
#                   string representing an existing file or 'NULL')
#                 Masks used to limit metric sampling region of the fixed image,
#                 defined per registration stage(Use "NULL" to omit a mask at a given
#                 stage)
#                 mutually_exclusive: fixed_image_mask
#         moving_image_mask: (a pathlike object or string representing an
#                   existing file)
#                 mask used to limit metric sampling region of the moving imagein all
#                 stages
#                 mutually_exclusive: moving_image_masks
#                 requires: fixed_image_mask
#         moving_image_masks: (a list of items which are a pathlike object or
#                   string representing an existing file or 'NULL')
#                 Masks used to limit metric sampling region of the moving image,
#                 defined per registration stage(Use "NULL" to omit a mask at a given
#                 stage)
#                 mutually_exclusive: moving_image_mask
#         save_state: (a pathlike object or string representing a file)
#                 Filename for saving the internal restorable state of the
#                 registration
#                 argument: ``--save-state %s``
#         restore_state: (a pathlike object or string representing an existing
#                   file)
#                 Filename for restoring the internal restorable state of the
#                 registration
#                 argument: ``--restore-state %s``
#         initial_moving_transform: (a list of items which are a pathlike
#                   object or string representing an existing file)
#                 A transform or a list of transforms that should be applied before
#                 the registration begins. Note that, when a list is given, the
#                 transformations are applied in reverse order.
#                 argument: ``%s``
#                 mutually_exclusive: initial_moving_transform_com
#         invert_initial_moving_transform: (a list of items which are a
#                   boolean)
#                 One boolean or a list of booleans that indicatewhether the
#                 inverse(s) of the transform(s) definedin initial_moving_transform
#                 should be used.
#                 mutually_exclusive: initial_moving_transform_com
#                 requires: initial_moving_transform
#         initial_moving_transform_com: (0 or 1 or 2)
#                 Align the moving_image and fixed_image before registration using the
#                 geometric center of the images (=0), the image intensities (=1), or
#                 the origin of the images (=2).
#                 argument: ``%s``
#                 mutually_exclusive: initial_moving_transform
#         metric_item_trait: ('CC' or 'MeanSquares' or 'Demons' or 'GC' or 'MI'
#                   or 'Mattes')
#         metric_stage_trait: ('CC' or 'MeanSquares' or 'Demons' or 'GC' or
#                   'MI' or 'Mattes' or a list of items which are 'CC' or
#                   'MeanSquares' or 'Demons' or 'GC' or 'MI' or 'Mattes')
#         metric_weight_item_trait: (a float, nipype default value: 1.0)
#         metric_weight_stage_trait: (a float or a list of items which are a
#                   float)
#         radius_bins_item_trait: (an integer, nipype default value: 5)
#         radius_bins_stage_trait: (an integer or a list of items which are an
#                   integer)
#         radius_or_number_of_bins: (a list of items which are an integer or a
#                   list of items which are an integer, nipype default value: [5])
#                 the number of bins in each stage for the MI and Mattes metric, the
#                 radius for other metrics
#                 requires: metric_weight
#         sampling_strategy_item_trait: ('None' or 'Regular' or 'Random' or
#                   None)
#         sampling_strategy_stage_trait: ('None' or 'Regular' or 'Random' or
#                   None or a list of items which are 'None' or 'Regular' or 'Random'
#                   or None)
#         sampling_strategy: (a list of items which are 'None' or 'Regular' or
#                   'Random' or None or a list of items which are 'None' or 'Regular'
#                   or 'Random' or None)
#                 the metric sampling strategy (strategies) for each stage
#                 requires: metric_weight
#         sampling_percentage_item_trait: (0.0 <= a floating point number <=
#                   1.0 or None)
#         sampling_percentage_stage_trait: (0.0 <= a floating point number <=
#                   1.0 or None or a list of items which are 0.0 <= a floating point
#                   number <= 1.0 or None)
#         sampling_percentage: (a list of items which are 0.0 <= a floating
#                   point number <= 1.0 or None or a list of items which are 0.0 <= a
#                   floating point number <= 1.0 or None)
#                 the metric sampling percentage(s) to use for each stage
#                 requires: sampling_strategy
#         use_estimate_learning_rate_once: (a list of items which are a
#                   boolean)
#         use_histogram_matching: (a boolean or a list of items which are a
#                   boolean, nipype default value: True)
#                 Histogram match the images before registration.
#         interpolation: ('Linear' or 'NearestNeighbor' or 'CosineWindowedSinc'
#                   or 'WelchWindowedSinc' or 'HammingWindowedSinc' or
#                   'LanczosWindowedSinc' or 'BSpline' or 'MultiLabel' or 'Gaussian'
#                   or 'GenericLabel', nipype default value: Linear)
#                 argument: ``%s``
#         interpolation_parameters: (a tuple of the form: (an integer) or a
#                   tuple of the form: (a float, a float) or a tuple of the form: (a
#                   string))
#         write_composite_transform: (a boolean, nipype default value: False)
#                 argument: ``--write-composite-transform %d``
#         collapse_output_transforms: (a boolean, nipype default value: True)
#                 Collapse output transforms. Specifically, enabling this option
#                 combines all adjacent linear transforms and composes all adjacent
#                 displacement field transforms before writing the results to disk.
#                 argument: ``--collapse-output-transforms %d``
#         initialize_transforms_per_stage: (a boolean, nipype default value:
#                   False)
#                 Initialize linear transforms from the previous stage. By enabling
#                 this option, the current linear stage transform is directly
#                 intialized from the previous stages linear transform; this allows
#                 multiple linear stages to be run where each stage directly updates
#                 the estimated linear transform from the previous stage. (e.g.
#                 Translation -> Rigid -> Affine).
#                 argument: ``--initialize-transforms-per-stage %d``
#         float: (a boolean)
#                 Use float instead of double for computations.
#                 argument: ``--float %d``
#         transform_parameters: (a list of items which are a tuple of the form:
#                   (a float) or a tuple of the form: (a float, a float, a float) or a
#                   tuple of the form: (a float, an integer, an integer, an integer)
#                   or a tuple of the form: (a float, an integer, a float, a float, a
#                   float, a float) or a tuple of the form: (a float, a float, a
#                   float, an integer) or a tuple of the form: (a float, an integer,
#                   an integer, an integer, an integer))
#         restrict_deformation: (a list of items which are a list of items
#                   which are 0.0 <= a floating point number <= 1.0)
#                 This option allows the user to restrict the optimization of the
#                 displacement field, translation, rigid or affine transform on a per-
#                 component basis. For example, if one wants to limit the deformation
#                 or rotation of 3-D volume to the first two dimensions, this is
#                 possible by specifying a weight vector of '1x1x0' for a deformation
#                 field or '1x1x0x1x1x0' for a rigid transformation. Low-dimensional
#                 restriction only works if there are no preceding transformations.
#         number_of_iterations: (a list of items which are a list of items
#                   which are an integer)
#         sigma_units: (a list of items which are 'mm' or 'vox')
#                 units for smoothing sigmas
#                 requires: smoothing_sigmas
#         convergence_threshold: (a list of at least 1 items which are a float,
#                   nipype default value: [1e-06])
#                 requires: number_of_iterations
#         convergence_window_size: (a list of at least 1 items which are an
#                   integer, nipype default value: [10])
#                 requires: convergence_threshold
#         output_transform_prefix: (a string, nipype default value: transform)
#                 argument: ``%s``
#         output_warped_image: (a boolean or a pathlike object or string
#                   representing a file)
#         output_inverse_warped_image: (a boolean or a pathlike object or
#                   string representing a file)
#                 requires: output_warped_image
#         winsorize_upper_quantile: (0.0 <= a floating point number <= 1.0,
#                   nipype default value: 1.0)
#                 The Upper quantile to clip image ranges
#                 argument: ``%s``
#         winsorize_lower_quantile: (0.0 <= a floating point number <= 1.0,
#                   nipype default value: 0.0)
#                 The Lower quantile to clip image ranges
#                 argument: ``%s``
#         verbose: (a boolean, nipype default value: False)
#                 argument: ``-v``
#         num_threads: (an integer, nipype default value: 1)
#                 Number of ITK threads to use
#         args: (a string)
#                 Additional parameters to the command
#                 argument: ``%s``
#         environ: (a dictionary with keys which are a bytes or None or a value
#                   of class 'str' and with values which are a bytes or None or a
#                   value of class 'str', nipype default value: {})
#                 Environment variables
#
# Outputs::
#
#         forward_transforms: (a list of items which are a pathlike object or
#                   string representing an existing file)
#                 List of output transforms for forward registration
#         reverse_forward_transforms: (a list of items which are a pathlike
#                   object or string representing an existing file)
#                 List of output transforms for forward registration reversed for
#                 antsApplyTransform
#         reverse_transforms: (a list of items which are a pathlike object or
#                   string representing an existing file)
#                 List of output transforms for reverse registration
#         forward_invert_flags: (a list of items which are a boolean)
#                 List of flags corresponding to the forward transforms
#         reverse_forward_invert_flags: (a list of items which are a boolean)
#                 List of flags corresponding to the forward transforms reversed for
#                 antsApplyTransform
#         reverse_invert_flags: (a list of items which are a boolean)
#                 List of flags corresponding to the reverse transforms
#         composite_transform: (a pathlike object or string representing an
#                   existing file)
#                 Composite transform file
#         inverse_composite_transform: (a pathlike object or string
#                   representing a file)
#                 Inverse composite transform file
#         warped_image: (a pathlike object or string representing a file)
#                 Outputs warped image
#         inverse_warped_image: (a pathlike object or string representing a
#                   file)
#                 Outputs the inverse of the warped image
#         save_state: (a pathlike object or string representing a file)
#                 The saved registration state to be restored
#         metric_value: (a float)
#                 the final value of metric
#         elapsed_time: (a float)
#                 the total elapsed time as reported by ANTs

# %% [markdown]
# #### Apply coregistration transforms to mean functional

# %%
interpolation = 'BSpline'
interpolation_parameters = (5,)

# %%
applyCoreg2MeanFunc = Node(ApplyTransforms(interpolation=interpolation,
                                          interpolation_parameters=interpolation_parameters), name = 'applyCoreg2MeanFunc')

# %%
if coregister and coreg_method == 'antsRegistration':
    if coreg_dir == 'func2struct':
        output_image = 'reg_meanFunc.nii'
        wf.connect([(meanFunc, applyCoreg2MeanFunc,[('mean_img', 'input_image')])]) 
        wf.connect([(datasource, applyCoreg2MeanFunc,[('UNI', 'reference_image')])]) 
        wf.connect([(coreg, applyCoreg2MeanFunc,[('forward_transforms', 'transforms')])]) 
        
    elif coreg_dir == 'struct2func':
        output_image = 'reg_UNI.nii'
        wf.connect([(meanFunc, applyCoreg2MeanFunc,[('mean_img', 'reference_image')])]) 
        wf.connect([(datasource, applyCoreg2MeanFunc,[('UNI', 'input_image')])]) 
        wf.connect([(coreg, applyCoreg2MeanFunc,[('forward_transforms', 'transforms')])]) 
        
        
    applyCoreg2MeanFunc.inputs.output_image = output_image
# Out:
# 221202-14:02:47,364 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.meanFunc, wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc): No edge data
# 221202-14:02:47,365 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.meanFunc, wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc): new edge data: {'connect': [('mean_img', 'input_image')]}
# 221202-14:02:47,366 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasource, wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc): No edge data
# 221202-14:02:47,367 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasource, wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc): new edge data: {'connect': [('UNI', 'reference_image')]}
# 221202-14:02:47,368 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.coreg, wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc): No edge data
# 221202-14:02:47,369 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.coreg, wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc): new edge data: {'connect': [('forward_transforms', 'transforms')]}

# %% [markdown]
# #### Apply coregistration transforms to all runs

# %%
applyCoreg = Node(ApplyTransforms(input_image_type=3,interpolation=interpolation,
                                  interpolation_parameters=interpolation_parameters), name = 'applyCoreg')

# %%
if coregister and coreg_method == 'antsRegistration':
    if coreg_dir == 'func2struct':
        wf.connect([(sliceTimingCorr,applyCoreg,[('timecorrected_files','input_image')])])
        wf.connect([(datasource, applyCoreg,[('UNI', 'reference_image')])]) 
        wf.connect([(coreg, applyCoreg,[('forward_transforms', 'transforms')])])
# Out:
# 221202-14:02:47,398 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sliceTimingCorr, wf_laminar_fMRI_func_pRF.applyCoreg): No edge data
# 221202-14:02:47,399 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sliceTimingCorr, wf_laminar_fMRI_func_pRF.applyCoreg): new edge data: {'connect': [('timecorrected_files', 'input_image')]}
# 221202-14:02:47,400 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasource, wf_laminar_fMRI_func_pRF.applyCoreg): No edge data
# 221202-14:02:47,400 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasource, wf_laminar_fMRI_func_pRF.applyCoreg): new edge data: {'connect': [('UNI', 'reference_image')]}
# 221202-14:02:47,401 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.coreg, wf_laminar_fMRI_func_pRF.applyCoreg): No edge data
# 221202-14:02:47,402 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.coreg, wf_laminar_fMRI_func_pRF.applyCoreg): new edge data: {'connect': [('forward_transforms', 'transforms')]}

# %%
ApplyTransforms.help()
# Out:
# Wraps the executable command ``antsApplyTransforms``.
#
# ApplyTransforms, applied to an input image, transforms it according to a
# reference image and a transform (or a set of transforms).
#
# Examples
# --------
#
# >>> from nipype.interfaces.ants import ApplyTransforms
# >>> at = ApplyTransforms()
# >>> at.inputs.input_image = 'moving1.nii'
# >>> at.inputs.reference_image = 'fixed1.nii'
# >>> at.inputs.transforms = 'identity'
# >>> at.cmdline
# 'antsApplyTransforms --default-value 0 --float 0 --input moving1.nii --interpolation Linear --output moving1_trans.nii --reference-image fixed1.nii --transform identity'
#
# >>> at = ApplyTransforms()
# >>> at.inputs.dimension = 3
# >>> at.inputs.input_image = 'moving1.nii'
# >>> at.inputs.reference_image = 'fixed1.nii'
# >>> at.inputs.output_image = 'deformed_moving1.nii'
# >>> at.inputs.interpolation = 'Linear'
# >>> at.inputs.default_value = 0
# >>> at.inputs.transforms = ['ants_Warp.nii.gz', 'trans.mat']
# >>> at.inputs.invert_transform_flags = [False, True]
# >>> at.cmdline
# 'antsApplyTransforms --default-value 0 --dimensionality 3 --float 0 --input moving1.nii --interpolation Linear --output deformed_moving1.nii --reference-image fixed1.nii --transform ants_Warp.nii.gz --transform [ trans.mat, 1 ]'
#
# >>> at1 = ApplyTransforms()
# >>> at1.inputs.dimension = 3
# >>> at1.inputs.input_image = 'moving1.nii'
# >>> at1.inputs.reference_image = 'fixed1.nii'
# >>> at1.inputs.output_image = 'deformed_moving1.nii'
# >>> at1.inputs.interpolation = 'BSpline'
# >>> at1.inputs.interpolation_parameters = (5,)
# >>> at1.inputs.default_value = 0
# >>> at1.inputs.transforms = ['ants_Warp.nii.gz', 'trans.mat']
# >>> at1.inputs.invert_transform_flags = [False, False]
# >>> at1.cmdline
# 'antsApplyTransforms --default-value 0 --dimensionality 3 --float 0 --input moving1.nii --interpolation BSpline[ 5 ] --output deformed_moving1.nii --reference-image fixed1.nii --transform ants_Warp.nii.gz --transform trans.mat'
#
# Identity transforms may be used as part of a chain:
#
# >>> at2 = ApplyTransforms()
# >>> at2.inputs.dimension = 3
# >>> at2.inputs.input_image = 'moving1.nii'
# >>> at2.inputs.reference_image = 'fixed1.nii'
# >>> at2.inputs.output_image = 'deformed_moving1.nii'
# >>> at2.inputs.interpolation = 'BSpline'
# >>> at2.inputs.interpolation_parameters = (5,)
# >>> at2.inputs.default_value = 0
# >>> at2.inputs.transforms = ['identity', 'ants_Warp.nii.gz', 'trans.mat']
# >>> at2.cmdline
# 'antsApplyTransforms --default-value 0 --dimensionality 3 --float 0 --input moving1.nii --interpolation BSpline[ 5 ] --output deformed_moving1.nii --reference-image fixed1.nii --transform identity --transform ants_Warp.nii.gz --transform trans.mat'
#
# Inputs::
#
#         [Mandatory]
#         input_image: (a pathlike object or string representing an existing
#                   file)
#                 image to apply transformation to (generally a coregistered
#                 functional)
#                 argument: ``--input %s``
#         reference_image: (a pathlike object or string representing an
#                   existing file)
#                 reference image space that you wish to warp INTO
#                 argument: ``--reference-image %s``
#         transforms: (a list of items which are a pathlike object or string
#                   representing an existing file or 'identity')
#                 transform files: will be applied in reverse order. For example, the
#                 last specified transform will be applied first.
#                 argument: ``%s``
#
#         [Optional]
#         dimension: (2 or 3 or 4)
#                 This option forces the image to be treated as a specified-
#                 dimensional image. If not specified, antsWarp tries to infer the
#                 dimensionality from the input image.
#                 argument: ``--dimensionality %d``
#         input_image_type: (0 or 1 or 2 or 3)
#                 Option specifying the input image type of scalar (default), vector,
#                 tensor, or time series.
#                 argument: ``--input-image-type %d``
#         output_image: (a string)
#                 output file name
#                 argument: ``--output %s``
#         out_postfix: (a string, nipype default value: _trans)
#                 Postfix that is appended to all output files (default = _trans)
#         interpolation: ('Linear' or 'NearestNeighbor' or 'CosineWindowedSinc'
#                   or 'WelchWindowedSinc' or 'HammingWindowedSinc' or
#                   'LanczosWindowedSinc' or 'MultiLabel' or 'Gaussian' or 'BSpline',
#                   nipype default value: Linear)
#                 argument: ``%s``
#         interpolation_parameters: (a tuple of the form: (an integer) or a
#                   tuple of the form: (a float, a float))
#         invert_transform_flags: (a list of items which are a boolean)
#         default_value: (a float, nipype default value: 0.0)
#                 argument: ``--default-value %g``
#         print_out_composite_warp_file: (a boolean)
#                 output a composite warp file instead of a transformed image
#                 requires: output_image
#         float: (a boolean, nipype default value: False)
#                 Use float instead of double for computations.
#                 argument: ``--float %d``
#         num_threads: (an integer, nipype default value: 1)
#                 Number of ITK threads to use
#         args: (a string)
#                 Additional parameters to the command
#                 argument: ``%s``
#         environ: (a dictionary with keys which are a bytes or None or a value
#                   of class 'str' and with values which are a bytes or None or a
#                   value of class 'str', nipype default value: {})
#                 Environment variables
#
# Outputs::
#
#         output_image: (a pathlike object or string representing an existing
#                   file)
#                 Warped image

# %% [markdown]
# ### Surface projection of functional runs

# %%
hemi_list = ['lh','rh']
reg_header = True
sampling_range_list = [-1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
sampling_method = 'point'
sampling_units = 'mm'
interp_method = 'trilinear'
out_type = 'mgh'

# %% [markdown]
# #### Iterate over depths and hemispheres

# %%
hemi_depth = Node(IdentityInterface(fields=['hemi','sampling_range']),name='hemi_depth')
hemi_depth.iterables = [('hemi', hemi_list), ('sampling_range', sampling_range_list)]
hemi_depth.synchronize = False

# %% [markdown]
# #### Mean functional

# %%
surfaceProjectMeanFunc = Node(SampleToSurface(reg_header=reg_header,
                                              sampling_method=sampling_method,
                                              sampling_units=sampling_units,
                                              out_type=out_type,
                                              interp_method=interp_method),name='surfaceProjectMeanFunc')

# %%
if coregister and coreg_method == 'antsRegistration':
    if coreg_dir == 'func2struct':
        wf.connect([(applyCoreg2MeanFunc,surfaceProjectMeanFunc,[('output_image', 'source_file')])]) 
        wf.connect([(subjects,surfaceProjectMeanFunc,[('subject_id', 'subject_id')])])
        wf.connect([(hemi_depth,surfaceProjectMeanFunc,[('hemi', 'hemi')])])
        wf.connect([(hemi_depth,surfaceProjectMeanFunc,[('sampling_range', 'sampling_range')])])
# Out:
# 221202-14:02:47,476 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc, wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc): No edge data
# 221202-14:02:47,477 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc, wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc): new edge data: {'connect': [('output_image', 'source_file')]}
# 221202-14:02:47,477 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc): No edge data
# 221202-14:02:47,478 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 221202-14:02:47,479 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc): No edge data
# 221202-14:02:47,479 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc): new edge data: {'connect': [('hemi', 'hemi')]}
# 221202-14:02:47,480 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc): Edge data exists: {'connect': [('hemi', 'hemi')]}
# 221202-14:02:47,481 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc): new edge data: {'connect': [('hemi', 'hemi'), ('sampling_range', 'sampling_range')]}

# %% [markdown]
# #### Other runs

# %%
surfaceProject = Node(SampleToSurface(reg_header=reg_header,
                                      sampling_method=sampling_method,
                                      sampling_units=sampling_units,
                                      out_type=out_type,
                                      interp_method=interp_method),name='surfaceProject')

# %%
if coregister and coreg_method == 'antsRegistration':
    if coreg_dir == 'func2struct':
        wf.connect([(applyCoreg,surfaceProject,[('output_image', 'source_file')])]) 
        wf.connect([(subjects,surfaceProject,[('subject_id', 'subject_id')])])
        wf.connect([(hemi_depth,surfaceProject,[('hemi', 'hemi')])])
        wf.connect([(hemi_depth,surfaceProject,[('sampling_range', 'sampling_range')])])
# Out:
# 221202-14:02:47,511 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyCoreg, wf_laminar_fMRI_func_pRF.surfaceProject): No edge data
# 221202-14:02:47,512 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyCoreg, wf_laminar_fMRI_func_pRF.surfaceProject): new edge data: {'connect': [('output_image', 'source_file')]}
# 221202-14:02:47,513 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.surfaceProject): No edge data
# 221202-14:02:47,513 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.surfaceProject): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 221202-14:02:47,514 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProject): No edge data
# 221202-14:02:47,515 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProject): new edge data: {'connect': [('hemi', 'hemi')]}
# 221202-14:02:47,515 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProject): Edge data exists: {'connect': [('hemi', 'hemi')]}
# 221202-14:02:47,516 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProject): new edge data: {'connect': [('hemi', 'hemi'), ('sampling_range', 'sampling_range')]}

# %% [markdown]
# #### Prepare occipital mask for pRF mapping

# %% [markdown]
# Surface project manual occipital mask

# %%
interp_method = 'nearest'

# %%
surfaceProjectOccipitalMask = Node(SampleToSurface(reg_header=reg_header,
                                      sampling_method=sampling_method,
                                      sampling_units=sampling_units,
                                      out_type=out_type,
                                      interp_method=interp_method),name='surfaceProjectOccipitalMask')

# %%
if coregister and coreg_method == 'antsRegistration':
    if coreg_dir == 'func2struct':
        wf.connect([(datasourceManualEdits,surfaceProjectOccipitalMask,[('manual_occipitalmask', 'source_file')])]) 
        wf.connect([(subjects,surfaceProjectOccipitalMask,[('subject_id', 'subject_id')])])
        wf.connect([(hemi_depth,surfaceProjectOccipitalMask,[('hemi', 'hemi')])])
        wf.connect([(hemi_depth,surfaceProjectOccipitalMask,[('sampling_range', 'sampling_range')])])
# Out:
# 221202-14:02:47,559 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasourceManualEdits, wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask): No edge data
# 221202-14:02:47,560 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.datasourceManualEdits, wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask): new edge data: {'connect': [('manual_occipitalmask', 'source_file')]}
# 221202-14:02:47,561 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask): No edge data
# 221202-14:02:47,562 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 221202-14:02:47,562 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask): No edge data
# 221202-14:02:47,563 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask): new edge data: {'connect': [('hemi', 'hemi')]}
# 221202-14:02:47,563 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask): Edge data exists: {'connect': [('hemi', 'hemi')]}
# 221202-14:02:47,564 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask): new edge data: {'connect': [('hemi', 'hemi'), ('sampling_range', 'sampling_range')]}

# %% [markdown]
# Make lable out of surface projection

# %%
def mri_vol2label_bash(subjects_dir,subject_id,working_dir,hemi,sampling_range,surface_file):
    from os.path import join as opj
    import os

    out_file = opj(working_dir,'_subject_id_'+subject_id,
                   '_hemi_'+hemi+'_sampling_range_'+str(sampling_range),'makeOccLabel',
                   hemi+'_occ_depth'+str(sampling_range)+'.label')
    bash_command = 'mri_vol2label --i '+surface_file+' --id 1 --surf '+subject_id + ' '+ hemi + ' --l '+out_file
    
    print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
    print(out_file)
    print(bash_command)
    print('mri_vol2label --i $OUTDIR/sub-01/lh_occ_depth0.0.mgh --id 1  --surf sub-01 lh  --l $OUTDIR/sub-01/lh_occ_depth0.0.label')
    print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')

    os.system(bash_command)
    
    return out_file

# %%
makeOccLabel = Node(Function(input_names = ['subjects_dir','subject_id','working_dir','hemi',
                                            'sampling_range','surface_file'],
                             output_names=['out_file'],
                             function=mri_vol2label_bash),
                    name='makeOccLabel')
makeOccLabel.inputs.working_dir = opj(der_dir,wf_name)
makeOccLabel.inputs.subjects_dir = subjects_dir

# %%
if coregister and coreg_method == 'antsRegistration':
    if coreg_dir == 'func2struct':
        wf.connect([(subjects,makeOccLabel,[('subject_id', 'subject_id')])])
        wf.connect([(hemi_depth,makeOccLabel,[('hemi', 'hemi')])])
        wf.connect([(hemi_depth,makeOccLabel,[('sampling_range', 'sampling_range')])])
        wf.connect([(surfaceProjectOccipitalMask,makeOccLabel,[('out_file', 'surface_file')])])
# Out:
# 221202-14:02:47,615 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.makeOccLabel): No edge data
# 221202-14:02:47,616 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.makeOccLabel): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 221202-14:02:47,617 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.makeOccLabel): No edge data
# 221202-14:02:47,617 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.makeOccLabel): new edge data: {'connect': [('hemi', 'hemi')]}
# 221202-14:02:47,618 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.makeOccLabel): Edge data exists: {'connect': [('hemi', 'hemi')]}
# 221202-14:02:47,619 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.makeOccLabel): new edge data: {'connect': [('hemi', 'hemi'), ('sampling_range', 'sampling_range')]}
# 221202-14:02:47,619 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask, wf_laminar_fMRI_func_pRF.makeOccLabel): No edge data
# 221202-14:02:47,620 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask, wf_laminar_fMRI_func_pRF.makeOccLabel): new edge data: {'connect': [('out_file', 'surface_file')]}

# %%
#operation = 'mul'   # ('add' or 'sub' or 'mul' or 'div' or 'rem' or 'max' or
                    # 'min')
                    # operation to perform
                    # flag: -%s, position: 4

# %%
#if coregister:
#    occipitalGM = Node(BinaryMaths(operation=operation), name='occipitalGM')

# %%
#if coregister:
#    wf.connect([(datasourceManualEdits,occipitalGM,[('binarizedmeanfunc', 'in_file')])]) 
#    wf.connect([(datasourceManualEdits,occipitalGM,[('occipital', 'operand_file')])])

# %% [markdown]
# ### Put data in sink
#
# A workflow working directory is like a cache. It contains not only the outputs of various processing stages, it also contains various extraneous information such as execution reports, hashfiles determining the input state of processes. All of this is embedded in a hierarchical structure that reflects the iterables that have been used in the workflow. This makes navigating the working directory a not so pleasant experience. And typically the user is interested in preserving only a small percentage of these outputs. The DataSink interface can be used to extract components from this cache and store it at a different location.

# %%
dataSink = Node(DataSink(), name='dataSink')
dataSink.inputs.base_directory = out_dir

# %%
# T1.nii
wf.connect([(convertT1ToNii,dataSink,[('out_file','func.anat')])])

# realigned func volumes (within and between session)
wf.connect([(applyRealign,dataSink,[('out_file','func.realign')])])

# mean functional
wf.connect([(meanFunc,dataSink,[('mean_img','func.meanFunc')])])

# binarized mean functional
wf.connect([(binarizeMeanFunc,dataSink,[('binary_file','func.meanFunc.@binarizedMeanFunc')])])


# # prepared fieldmap
# wf.connect([(prepFieldMap,dataSink,[('out_fieldmap','func.prepFieldMap')])])

# # unwarped func volumes
# if unwarp:
#     wf.connect([(unwarping,dataSink,[('unwarped_file','func.unwarp')])])

# slice-time corrected func volumes
wf.connect([(sliceTimingCorr,dataSink,[('timecorrected_files','func.sliceTimeCorr')])])


# coregistered T1 and transformation matrices
if coregister:
    if coreg_method == 'antsRegistration':
        wf.connect([(coreg,dataSink,[('warped_image','func.coreg')])])
        wf.connect([(coreg, dataSink,[('forward_transforms', 'func.coreg.@forwardTransform')])]) 
        wf.connect([(coreg, dataSink,[('reverse_transforms', 'func.coreg.@reverseTransform')])])

        wf.connect([(applyCoreg, dataSink,[('output_image', 'func.coreg.@reg_func')])])
        
    elif coreg_method == 'itk-snap':
        wf.connect([(coreg,dataSink,[('output_image','func.coreg')])])
    
## occipital GM mask for pRF mapping
#if manual_edits:
#    wf.connect([(occipitalGM,dataSink,[('out_file','func.occipitalGM')])])
    
#if coreg_method == 'flirt':
#    wf.connect([(coreg,dataSink,[('out_file','func.coreg')])])
#    wf.connect([(coreg,dataSink,[('out_matrix_file','func.coreg.@out_matrix_file')])])
#elif coreg_method == 'freesurfer':
#    wf.connect([(coreg,dataSink,[('out_file','func.coreg')])])
#    wf.connect([(coreg,dataSink,[('out_matrix_file','func.coreg.@out_matrix_file')])])
#elif coreg_method == 'antsRegistration':
#    wf.connect([(coreg,dataSink,[('warped_image','func.coreg')])])
# Out:
# 221202-14:02:47,696 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.convertT1ToNii, wf_laminar_fMRI_func_pRF.dataSink): No edge data
# 221202-14:02:47,697 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.convertT1ToNii, wf_laminar_fMRI_func_pRF.dataSink): new edge data: {'connect': [('out_file', 'func.anat')]}
# 221202-14:02:47,698 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyRealign, wf_laminar_fMRI_func_pRF.dataSink): No edge data
# 221202-14:02:47,699 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyRealign, wf_laminar_fMRI_func_pRF.dataSink): new edge data: {'connect': [('out_file', 'func.realign')]}
# 221202-14:02:47,700 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.meanFunc, wf_laminar_fMRI_func_pRF.dataSink): No edge data
# 221202-14:02:47,700 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.meanFunc, wf_laminar_fMRI_func_pRF.dataSink): new edge data: {'connect': [('mean_img', 'func.meanFunc')]}
# 221202-14:02:47,701 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.binarizeMeanFunc, wf_laminar_fMRI_func_pRF.dataSink): No edge data
# 221202-14:02:47,702 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.binarizeMeanFunc, wf_laminar_fMRI_func_pRF.dataSink): new edge data: {'connect': [('binary_file', 'func.meanFunc.@binarizedMeanFunc')]}
# 221202-14:02:47,703 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sliceTimingCorr, wf_laminar_fMRI_func_pRF.dataSink): No edge data
# 221202-14:02:47,703 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.sliceTimingCorr, wf_laminar_fMRI_func_pRF.dataSink): new edge data: {'connect': [('timecorrected_files', 'func.sliceTimeCorr')]}
# 221202-14:02:47,704 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.coreg, wf_laminar_fMRI_func_pRF.dataSink): No edge data
# 221202-14:02:47,705 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.coreg, wf_laminar_fMRI_func_pRF.dataSink): new edge data: {'connect': [('warped_image', 'func.coreg')]}
# 221202-14:02:47,706 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.coreg, wf_laminar_fMRI_func_pRF.dataSink): Edge data exists: {'connect': [('warped_image', 'func.coreg')]}
# 221202-14:02:47,706 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.coreg, wf_laminar_fMRI_func_pRF.dataSink): new edge data: {'connect': [('warped_image', 'func.coreg'), ('forward_transforms', 'func.coreg.@forwardTransform')]}
# 221202-14:02:47,707 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.coreg, wf_laminar_fMRI_func_pRF.dataSink): Edge data exists: {'connect': [('warped_image', 'func.coreg'), ('forward_transforms', 'func.coreg.@forwardTransform')]}
# 221202-14:02:47,708 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.coreg, wf_laminar_fMRI_func_pRF.dataSink): new edge data: {'connect': [('warped_image', 'func.coreg'), ('forward_transforms', 'func.coreg.@forwardTransform'), ('reverse_transforms', 'func.coreg.@reverseTransform')]}
# 221202-14:02:47,709 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyCoreg, wf_laminar_fMRI_func_pRF.dataSink): No edge data
# 221202-14:02:47,709 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyCoreg, wf_laminar_fMRI_func_pRF.dataSink): new edge data: {'connect': [('output_image', 'func.coreg.@reg_func')]}

# %% [markdown]
# ### Put pRF analysis data in separate sink

# %%
prfSink = Node(DataSink(), name='prfSink')
prfSink.inputs.base_directory = pRF_dir

# %%
if coregister and coreg_method == 'antsRegistration':
    # coregistered mean functional
    wf.connect([(applyCoreg2MeanFunc,prfSink,[('output_image','data.coreg_meanFunc')])])
    
    # coregistered other functional runs
    wf.connect([(applyCoreg,prfSink,[('output_image','data.coreg')])])
    
    # surface projected mean functional
    wf.connect([(surfaceProjectMeanFunc,prfSink,[('out_file','data.surfs_meanFunc')])])
    
    # surface projected other functional runs
    wf.connect([(surfaceProject,prfSink,[('out_file','data.surfs')])])
    
    # occipital labels
    wf.connect([(makeOccLabel,prfSink,[('out_file','data.occLabels')])])
# Out:
# 221202-14:02:47,749 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc, wf_laminar_fMRI_func_pRF.prfSink): No edge data
# 221202-14:02:47,750 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc, wf_laminar_fMRI_func_pRF.prfSink): new edge data: {'connect': [('output_image', 'data.coreg_meanFunc')]}
# 221202-14:02:47,750 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyCoreg, wf_laminar_fMRI_func_pRF.prfSink): No edge data
# 221202-14:02:47,751 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.applyCoreg, wf_laminar_fMRI_func_pRF.prfSink): new edge data: {'connect': [('output_image', 'data.coreg')]}
# 221202-14:02:47,752 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc, wf_laminar_fMRI_func_pRF.prfSink): No edge data
# 221202-14:02:47,753 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc, wf_laminar_fMRI_func_pRF.prfSink): new edge data: {'connect': [('out_file', 'data.surfs_meanFunc')]}
# 221202-14:02:47,753 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.surfaceProject, wf_laminar_fMRI_func_pRF.prfSink): No edge data
# 221202-14:02:47,754 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.surfaceProject, wf_laminar_fMRI_func_pRF.prfSink): new edge data: {'connect': [('out_file', 'data.surfs')]}
# 221202-14:02:47,755 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.makeOccLabel, wf_laminar_fMRI_func_pRF.prfSink): No edge data
# 221202-14:02:47,755 nipype.workflow DEBUG:
# 	 (wf_laminar_fMRI_func_pRF.makeOccLabel, wf_laminar_fMRI_func_pRF.prfSink): new edge data: {'connect': [('out_file', 'data.occLabels')]}

# %% [markdown]
# ### Write graph for visualization and run pipeline

# %%
if write_graph:
    wf.write_graph("workflowgraph.dot",graph2use='exec', format='svg', simple_form=True)
# Out:
# 221202-14:02:47,772 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: wf_laminar_fMRI_func_pRF
# 221202-14:02:47,786 nipype.workflow DEBUG:
# 	 expanding workflow: wf_laminar_fMRI_func_pRF
# 221202-14:02:47,792 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.subjects
# 221202-14:02:47,794 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.datasource
# 221202-14:02:47,795 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.convertT1ToNii
# 221202-14:02:47,796 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.datasourceFunc
# 221202-14:02:47,796 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.sessions
# 221202-14:02:47,797 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.datasourceManualEdits
# 221202-14:02:47,797 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.betMagnImg
# 221202-14:02:47,798 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.discardDummies
# 221202-14:02:47,805 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:47,806 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.concatenateMeans
# 221202-14:02:47,808 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.mcflirtBetweenSess
# 221202-14:02:47,808 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.betweenMat
# 221202-14:02:47,809 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.concatenateTransforms
# 221202-14:02:47,810 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.copyTransforms
# 221202-14:02:47,811 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.applyRealign
# 221202-14:02:47,811 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:47,812 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.acquisitionParams
# 221202-14:02:47,812 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.concatenateFunc
# 221202-14:02:47,813 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.meanFunc
# 221202-14:02:47,813 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.binarizeMeanFunc
# 221202-14:02:47,814 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.coreg
# 221202-14:02:47,814 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc
# 221202-14:02:47,815 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.applyCoreg
# 221202-14:02:47,815 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc
# 221202-14:02:47,816 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.hemi_depth
# 221202-14:02:47,816 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.surfaceProject
# 221202-14:02:47,817 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask
# 221202-14:02:47,817 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.makeOccLabel
# 221202-14:02:47,818 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.dataSink
# 221202-14:02:47,818 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.prfSink
# 221202-14:02:47,819 nipype.workflow DEBUG:
# 	 finished expanding workflow: wf_laminar_fMRI_func_pRF
# 221202-14:02:47,835 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 221202-14:02:47,845 nipype.workflow DEBUG:
# 	 [Node] sliceTimingCorr - setting input num_slices = 50
# 221202-14:02:47,846 nipype.workflow DEBUG:
# 	 [Node] sliceTimingCorr - setting input slice_order = [1.505, 0.0, 1.565, 0.06, 1.6275, 0.12000000001, 1.6875, 0.18000000001, 1.7475, 0.24000000001000002, 1.8075000000099999, 0.30250000001, 1.86750000001, 0.3625, 1.92750000001, 0.4225, 1.9875, 0.4825, 2.0475, 0.5425, 2.1075, 0.60250000001, 2.1675, 0.66250000001, 2.23, 0.7225, 2.29000000001, 0.7825, 2.35000000001, 0.8425, 2.41, 0.9025, 2.47, 0.965, 2.53, 1.02500000001, 2.59, 1.08500000001, 2.65000000001, 1.145, 2.71000000001, 1.205, 2.77, 1.265, 2.83, 1.325, 2.8925, 1.3850000000099998, 2.9525, 1.4450000000099998]
# 221202-14:02:47,847 nipype.workflow DEBUG:
# 	 [Node] sliceTimingCorr - setting input time_repetition = 3.0
# 221202-14:02:47,848 nipype.workflow DEBUG:
# 	 [Node] sliceTimingCorr - setting input time_acquisition = 2.94
# 221202-14:02:47,848 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.acquisitionParams from the graph.
# 221202-14:02:47,849 nipype.workflow DEBUG:
# 	 Detected iterable nodes [wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.hemi_depth]
# 221202-14:02:47,850 nipype.workflow DEBUG:
# 	 Expanding the iterable node wf_laminar_fMRI_func_pRF.subjects...
# 221202-14:02:47,850 nipype.workflow DEBUG:
# 	 node: wf_laminar_fMRI_func_pRF.subjects iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x2aaae69cce18>}
# 221202-14:02:47,859 nipype.workflow DEBUG:
# 	 ('subnodes:', [wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.datasource, wf_laminar_fMRI_func_pRF.convertT1ToNii, wf_laminar_fMRI_func_pRF.dataSink, wf_laminar_fMRI_func_pRF.betMagnImg, wf_laminar_fMRI_func_pRF.coreg, wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc, wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc, wf_laminar_fMRI_func_pRF.prfSink, wf_laminar_fMRI_func_pRF.applyCoreg, wf_laminar_fMRI_func_pRF.surfaceProject, wf_laminar_fMRI_func_pRF.datasourceFunc, wf_laminar_fMRI_func_pRF.discardDummies, wf_laminar_fMRI_func_pRF.mcflirtWithinSess, wf_laminar_fMRI_func_pRF.concatenateMeans, wf_laminar_fMRI_func_pRF.mcflirtBetweenSess, wf_laminar_fMRI_func_pRF.betweenMat, wf_laminar_fMRI_func_pRF.concatenateTransforms, wf_laminar_fMRI_func_pRF.copyTransforms, wf_laminar_fMRI_func_pRF.applyRealign, wf_laminar_fMRI_func_pRF.sliceTimingCorr, wf_laminar_fMRI_func_pRF.concatenateFunc, wf_laminar_fMRI_func_pRF.meanFunc, wf_laminar_fMRI_func_pRF.binarizeMeanFunc, wf_laminar_fMRI_func_pRF.datasourceManualEdits, wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask, wf_laminar_fMRI_func_pRF.makeOccLabel])
# 221202-14:02:47,887 nipype.workflow DEBUG:
# 	 [Node] subjects - setting input subject_id = sub-01
# 221202-14:02:47,887 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_sub-01
# 221202-14:02:47,889 nipype.workflow DEBUG:
# 	 Expanding the iterable node wf_laminar_fMRI_func_pRF.sessions...
# 221202-14:02:47,889 nipype.workflow DEBUG:
# 	 Excised the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join node in-edge.
# 221202-14:02:47,890 nipype.workflow DEBUG:
# 	 Excised the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join node in-edge.
# 221202-14:02:47,890 nipype.workflow DEBUG:
# 	 node: wf_laminar_fMRI_func_pRF.sessions iterables: {'sess_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x2aaae69cc730>, 'sess_nvol': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x2aaae69ccc80>, 'sess_nr': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x2aaae6a6e268>}
# 221202-14:02:47,891 nipype.workflow DEBUG:
# 	 ('subnodes:', [wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.datasourceFunc.a0, wf_laminar_fMRI_func_pRF.discardDummies.a0, wf_laminar_fMRI_func_pRF.mcflirtWithinSess.a0, wf_laminar_fMRI_func_pRF.concatenateTransforms.a0, wf_laminar_fMRI_func_pRF.copyTransforms.a0, wf_laminar_fMRI_func_pRF.applyRealign.a0, wf_laminar_fMRI_func_pRF.sliceTimingCorr.a0, wf_laminar_fMRI_func_pRF.applyCoreg.a0, wf_laminar_fMRI_func_pRF.surfaceProject.a0, wf_laminar_fMRI_func_pRF.prfSink.a0, wf_laminar_fMRI_func_pRF.dataSink.a0, wf_laminar_fMRI_func_pRF.betweenMat.a0])
# 221202-14:02:47,905 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = task-bar_run-01
# 221202-14:02:47,906 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 0
# 221202-14:02:47,907 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 124
# 221202-14:02:47,907 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_task-bar_run-01_sess_nr_0_sess_nvol_124
# 221202-14:02:47,916 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = task-bar_run-02
# 221202-14:02:47,921 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 1
# 221202-14:02:47,923 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 124
# 221202-14:02:47,925 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_task-bar_run-02_sess_nr_1_sess_nvol_124
# 221202-14:02:47,933 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = task-pol_run-01
# 221202-14:02:47,935 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 2
# 221202-14:02:47,936 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 254
# 221202-14:02:47,939 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_task-pol_run-01_sess_nr_2_sess_nvol_254
# 221202-14:02:47,947 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = task-pol_run-02
# 221202-14:02:47,950 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 3
# 221202-14:02:47,952 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 254
# 221202-14:02:47,954 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_task-pol_run-02_sess_nr_3_sess_nvol_254
# 221202-14:02:47,962 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = task-ecc_run-01
# 221202-14:02:47,964 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 4
# 221202-14:02:47,966 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 131
# 221202-14:02:47,967 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_task-ecc_run-01_sess_nr_4_sess_nvol_131
# 221202-14:02:47,974 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = task-ecc_run-02
# 221202-14:02:47,978 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 5
# 221202-14:02:47,980 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 131
# 221202-14:02:47,982 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_task-ecc_run-02_sess_nr_5_sess_nvol_131
# 221202-14:02:47,990 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = rest_run-01
# 221202-14:02:47,992 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 6
# 221202-14:02:47,994 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 50
# 221202-14:02:47,997 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_rest_run-01_sess_nr_6_sess_nvol_50
# 221202-14:02:47,999 nipype.workflow DEBUG:
# 	 The join node wf_laminar_fMRI_func_pRF.concatenateMeans input wf_laminar_fMRI_func_pRF.mcflirtWithinSess.a0 was expanded to 7 nodes.
# 221202-14:02:48,1 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ1'}.
# 221202-14:02:48,3 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ2'}.
# 221202-14:02:48,5 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ3'}.
# 221202-14:02:48,7 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ4'}.
# 221202-14:02:48,9 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ5'}.
# 221202-14:02:48,11 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ6'}.
# 221202-14:02:48,13 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ7'}.
# 221202-14:02:48,15 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ1.
# 221202-14:02:48,17 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:48,18 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ2.
# 221202-14:02:48,21 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:48,22 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ3.
# 221202-14:02:48,23 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:48,24 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ4.
# 221202-14:02:48,24 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:48,29 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ5.
# 221202-14:02:48,30 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:48,30 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ6.
# 221202-14:02:48,31 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:48,31 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ7.
# 221202-14:02:48,32 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:48,32 nipype.workflow DEBUG:
# 	 The join node wf_laminar_fMRI_func_pRF.concatenateFunc input wf_laminar_fMRI_func_pRF.sliceTimingCorr.a0 was expanded to 7 nodes.
# 221202-14:02:48,33 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ1'}.
# 221202-14:02:48,34 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ2'}.
# 221202-14:02:48,34 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ3'}.
# 221202-14:02:48,35 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ4'}.
# 221202-14:02:48,35 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ5'}.
# 221202-14:02:48,36 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ6'}.
# 221202-14:02:48,36 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ7'}.
# 221202-14:02:48,37 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ1.
# 221202-14:02:48,37 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:48,38 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ2.
# 221202-14:02:48,38 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:48,39 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ3.
# 221202-14:02:48,39 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:48,40 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ4.
# 221202-14:02:48,40 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:48,41 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ5.
# 221202-14:02:48,41 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:48,42 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ6.
# 221202-14:02:48,42 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:48,43 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ7.
# 221202-14:02:48,43 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:48,46 nipype.workflow DEBUG:
# 	 Expanding the iterable node wf_laminar_fMRI_func_pRF.hemi_depth...
# 221202-14:02:48,50 nipype.workflow DEBUG:
# 	 node: wf_laminar_fMRI_func_pRF.hemi_depth iterables: {'hemi': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x2aaae6a6e048>, 'sampling_range': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x2aaae6a6e0d0>}
# 221202-14:02:48,50 nipype.workflow DEBUG:
# 	 ('subnodes:', [wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc.a0, wf_laminar_fMRI_func_pRF.prfSink.a0.a0, wf_laminar_fMRI_func_pRF.prfSink.a0.a1, wf_laminar_fMRI_func_pRF.prfSink.a0.a2, wf_laminar_fMRI_func_pRF.prfSink.a0.a3, wf_laminar_fMRI_func_pRF.prfSink.a0.a4, wf_laminar_fMRI_func_pRF.prfSink.a0.a5, wf_laminar_fMRI_func_pRF.prfSink.a0.a6, wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask.a0, wf_laminar_fMRI_func_pRF.makeOccLabel.a0, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a0, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a1, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a2, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a3, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a4, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a5, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a6])
# 221202-14:02:48,61 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:48,72 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = -1.5
# 221202-14:02:48,73 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_-1.5
# 221202-14:02:48,83 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:48,84 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = -1.0
# 221202-14:02:48,84 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_-1.0
# 221202-14:02:48,104 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:48,105 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = -0.5
# 221202-14:02:48,105 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_-0.5
# 221202-14:02:48,117 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:48,136 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 0.0
# 221202-14:02:48,137 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_0.0
# 221202-14:02:48,149 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:48,151 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 0.5
# 221202-14:02:48,153 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_0.5
# 221202-14:02:48,165 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:48,167 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 1.0
# 221202-14:02:48,169 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_1.0
# 221202-14:02:48,181 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:48,183 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 1.5
# 221202-14:02:48,185 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_1.5
# 221202-14:02:48,197 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:48,199 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 2.0
# 221202-14:02:48,201 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_2.0
# 221202-14:02:48,213 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:48,215 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 2.5
# 221202-14:02:48,217 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_2.5
# 221202-14:02:48,228 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:48,231 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = -1.5
# 221202-14:02:48,232 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_-1.5
# 221202-14:02:48,245 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:48,247 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = -1.0
# 221202-14:02:48,249 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_-1.0
# 221202-14:02:48,262 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:48,264 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = -0.5
# 221202-14:02:48,266 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_-0.5
# 221202-14:02:48,278 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:48,280 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 0.0
# 221202-14:02:48,282 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_0.0
# 221202-14:02:48,294 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:48,296 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 0.5
# 221202-14:02:48,298 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_0.5
# 221202-14:02:48,310 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:48,312 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 1.0
# 221202-14:02:48,314 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_1.0
# 221202-14:02:48,326 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:48,328 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 1.5
# 221202-14:02:48,330 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_1.5
# 221202-14:02:48,342 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:48,344 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 2.0
# 221202-14:02:48,346 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_2.0
# 221202-14:02:48,357 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:48,360 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 2.5
# 221202-14:02:48,362 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_2.5
# 221202-14:02:48,368 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 221202-14:02:48,374 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:48,376 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:48,378 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:48,379 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,382 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,383 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,385 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,387 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,389 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,391 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,393 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 2.5
# 221202-14:02:48,394 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 2.5
# 221202-14:02:48,396 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 2.5
# 221202-14:02:48,398 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,400 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,400 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,401 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,401 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,402 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,402 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,409 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:48,410 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:48,410 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:48,411 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:48,411 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,412 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,412 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,413 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,413 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,414 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,414 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,415 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 2.0
# 221202-14:02:48,415 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 2.0
# 221202-14:02:48,416 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 2.0
# 221202-14:02:48,416 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,416 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,417 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,417 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,418 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,418 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,419 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,419 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:48,420 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:48,420 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:48,421 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:48,421 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,422 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,422 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,423 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,423 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,424 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,424 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,425 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 1.5
# 221202-14:02:48,425 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 1.5
# 221202-14:02:48,426 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 1.5
# 221202-14:02:48,426 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:48,427 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:48,427 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:48,428 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:48,430 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:48,431 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:48,431 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:48,432 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:48,433 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:48,434 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:48,434 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:48,443 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,444 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,445 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,445 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,445 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,446 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,446 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,447 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 1.0
# 221202-14:02:48,448 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 1.0
# 221202-14:02:48,448 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 1.0
# 221202-14:02:48,449 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:48,449 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:48,450 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:48,450 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:48,451 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:48,451 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:48,452 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:48,452 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:48,453 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:48,454 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:48,454 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:48,455 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,455 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,468 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,468 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,469 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,470 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,470 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,471 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 0.5
# 221202-14:02:48,471 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 0.5
# 221202-14:02:48,472 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 0.5
# 221202-14:02:48,472 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:48,473 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:48,473 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:48,474 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:48,474 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:48,475 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:48,475 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:48,476 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:48,476 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:48,477 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:48,477 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:48,478 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,478 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,479 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,479 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,480 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,481 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,481 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,482 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 0.0
# 221202-14:02:48,482 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 0.0
# 221202-14:02:48,483 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 0.0
# 221202-14:02:48,483 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:48,484 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:48,484 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:48,485 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:48,486 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:48,494 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:48,494 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:48,495 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:48,496 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:48,496 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:48,497 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:48,497 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,498 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,498 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,499 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,499 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,500 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,500 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,501 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = -0.5
# 221202-14:02:48,501 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = -0.5
# 221202-14:02:48,502 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = -0.5
# 221202-14:02:48,502 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:48,503 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:48,503 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:48,512 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:48,513 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:48,514 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:48,514 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:48,515 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:48,515 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:48,516 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:48,516 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:48,517 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,517 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,518 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,518 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,519 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,520 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,520 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,521 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = -1.0
# 221202-14:02:48,521 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = -1.0
# 221202-14:02:48,522 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = -1.0
# 221202-14:02:48,522 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:48,523 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:48,523 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:48,524 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:48,524 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:48,525 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:48,527 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:48,527 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:48,529 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:48,530 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:48,531 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:48,531 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,532 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,532 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,541 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,542 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,543 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,543 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:48,543 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = -1.5
# 221202-14:02:48,544 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = -1.5
# 221202-14:02:48,545 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = -1.5
# 221202-14:02:48,545 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:48,546 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:48,546 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:48,547 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:48,547 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:48,548 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:48,548 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:48,549 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:48,549 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = lh
# 221202-14:02:48,550 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = lh
# 221202-14:02:48,550 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = lh
# 221202-14:02:48,551 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,551 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,552 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,562 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,562 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,563 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,563 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,564 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 2.5
# 221202-14:02:48,564 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 2.5
# 221202-14:02:48,565 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 2.5
# 221202-14:02:48,565 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,566 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,566 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,567 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,567 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,568 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,568 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:48,569 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:48,570 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = lh
# 221202-14:02:48,570 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = lh
# 221202-14:02:48,571 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = lh
# 221202-14:02:48,571 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,572 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,572 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,573 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,573 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,574 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,575 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:48,575 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 2.0
# 221202-14:02:48,576 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 2.0
# 221202-14:02:48,586 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 2.0
# 221202-14:02:48,586 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,587 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,587 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,588 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,588 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,589 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:48,589 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# ...
# 221202-14:02:48,812 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,813 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,814 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,824 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,824 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,825 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,825 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,826 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,826 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,827 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,827 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,828 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,828 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,829 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,829 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,830 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,830 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,831 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,831 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,832 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,833 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,833 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,834 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,834 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,835 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,835 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,836 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,845 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,846 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,847 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,847 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,848 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,848 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,849 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,849 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,850 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,850 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,851 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,851 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,852 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,852 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,853 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,853 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,854 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,855 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,855 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,856 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,856 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,857 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,858 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,859 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,859 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,869 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,869 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,870 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,870 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,871 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,871 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,872 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,872 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,873 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,873 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,874 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,874 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,875 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,875 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,876 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,876 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,877 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,877 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,878 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,878 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,879 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,880 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,880 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,881 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,882 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,891 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,892 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,893 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,893 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,894 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,894 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,895 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,895 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,896 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,896 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,897 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,897 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,898 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,898 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,899 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,900 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,900 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,901 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,901 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,902 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,902 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,903 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,903 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,905 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,906 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,907 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,907 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,910 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,911 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,911 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,912 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,912 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,913 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,921 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,922 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,922 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,923 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,923 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,924 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,924 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,925 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,926 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,926 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,927 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,927 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,928 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,928 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,929 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,929 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,930 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,930 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,931 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,932 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,933 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,933 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,934 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,934 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,935 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,935 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,945 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,945 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,946 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,946 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,947 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input subject_id = sub-01
# 221202-14:02:48,947 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input subject_id = sub-01
# 221202-14:02:48,948 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,948 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,949 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,949 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,950 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input subject_id = sub-01
# 221202-14:02:48,950 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input subject_id = sub-01
# 221202-14:02:48,951 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.subjects from the graph.
# 221202-14:02:49,320 nipype.workflow DEBUG:
# 	 using input graph
# 221202-14:02:50,730 nipype.workflow DEBUG:
# 	 creating dot graph
# 221202-14:02:51,76 nipype.workflow INFO:
# 	 Generated workflow graph: /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/workflowgraph.svg (graph2use=exec, simple_form=True).

# %%
if run_pipeline:
    if n_procs == 1:
        wf.run()
    else:
        wf.run('MultiProc', plugin_args={'n_procs': n_procs})
# Out:
# 221202-14:02:51,120 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: wf_laminar_fMRI_func_pRF
# 221202-14:02:51,134 nipype.workflow DEBUG:
# 	 expanding workflow: wf_laminar_fMRI_func_pRF
# 221202-14:02:51,135 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.subjects
# 221202-14:02:51,138 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.datasource
# 221202-14:02:51,140 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.convertT1ToNii
# 221202-14:02:51,142 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.datasourceFunc
# 221202-14:02:51,144 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.sessions
# 221202-14:02:51,146 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.datasourceManualEdits
# 221202-14:02:51,148 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.betMagnImg
# 221202-14:02:51,149 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.discardDummies
# 221202-14:02:51,151 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:51,152 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.concatenateMeans
# 221202-14:02:51,155 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.mcflirtBetweenSess
# 221202-14:02:51,156 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.betweenMat
# 221202-14:02:51,157 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.concatenateTransforms
# 221202-14:02:51,158 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.copyTransforms
# 221202-14:02:51,158 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.applyRealign
# 221202-14:02:51,159 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:51,159 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.acquisitionParams
# 221202-14:02:51,160 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.concatenateFunc
# 221202-14:02:51,160 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.meanFunc
# 221202-14:02:51,161 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.binarizeMeanFunc
# 221202-14:02:51,161 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.coreg
# 221202-14:02:51,162 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc
# 221202-14:02:51,172 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.applyCoreg
# 221202-14:02:51,173 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc
# 221202-14:02:51,173 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.hemi_depth
# 221202-14:02:51,174 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.surfaceProject
# 221202-14:02:51,174 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask
# 221202-14:02:51,175 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.makeOccLabel
# 221202-14:02:51,175 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.dataSink
# 221202-14:02:51,176 nipype.workflow DEBUG:
# 	 processing node: wf_laminar_fMRI_func_pRF.prfSink
# 221202-14:02:51,176 nipype.workflow DEBUG:
# 	 finished expanding workflow: wf_laminar_fMRI_func_pRF
# 221202-14:02:51,177 nipype.workflow INFO:
# 	 Workflow wf_laminar_fMRI_func_pRF settings: ['check', 'execution', 'logging', 'monitoring']
# 221202-14:02:51,189 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 221202-14:02:51,190 nipype.workflow DEBUG:
# 	 [Node] sliceTimingCorr - setting input num_slices = 50
# 221202-14:02:51,191 nipype.workflow DEBUG:
# 	 [Node] sliceTimingCorr - setting input slice_order = [1.505, 0.0, 1.565, 0.06, 1.6275, 0.12000000001, 1.6875, 0.18000000001, 1.7475, 0.24000000001000002, 1.8075000000099999, 0.30250000001, 1.86750000001, 0.3625, 1.92750000001, 0.4225, 1.9875, 0.4825, 2.0475, 0.5425, 2.1075, 0.60250000001, 2.1675, 0.66250000001, 2.23, 0.7225, 2.29000000001, 0.7825, 2.35000000001, 0.8425, 2.41, 0.9025, 2.47, 0.965, 2.53, 1.02500000001, 2.59, 1.08500000001, 2.65000000001, 1.145, 2.71000000001, 1.205, 2.77, 1.265, 2.83, 1.325, 2.8925, 1.3850000000099998, 2.9525, 1.4450000000099998]
# 221202-14:02:51,192 nipype.workflow DEBUG:
# 	 [Node] sliceTimingCorr - setting input time_repetition = 3.0
# 221202-14:02:51,192 nipype.workflow DEBUG:
# 	 [Node] sliceTimingCorr - setting input time_acquisition = 2.94
# 221202-14:02:51,205 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.acquisitionParams from the graph.
# 221202-14:02:51,206 nipype.workflow DEBUG:
# 	 Detected iterable nodes [wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.hemi_depth]
# 221202-14:02:51,207 nipype.workflow DEBUG:
# 	 Expanding the iterable node wf_laminar_fMRI_func_pRF.subjects...
# 221202-14:02:51,207 nipype.workflow DEBUG:
# 	 node: wf_laminar_fMRI_func_pRF.subjects iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x2aaae4331950>}
# 221202-14:02:51,208 nipype.workflow DEBUG:
# 	 ('subnodes:', [wf_laminar_fMRI_func_pRF.subjects, wf_laminar_fMRI_func_pRF.datasource, wf_laminar_fMRI_func_pRF.convertT1ToNii, wf_laminar_fMRI_func_pRF.dataSink, wf_laminar_fMRI_func_pRF.betMagnImg, wf_laminar_fMRI_func_pRF.coreg, wf_laminar_fMRI_func_pRF.applyCoreg2MeanFunc, wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc, wf_laminar_fMRI_func_pRF.prfSink, wf_laminar_fMRI_func_pRF.applyCoreg, wf_laminar_fMRI_func_pRF.surfaceProject, wf_laminar_fMRI_func_pRF.datasourceFunc, wf_laminar_fMRI_func_pRF.discardDummies, wf_laminar_fMRI_func_pRF.mcflirtWithinSess, wf_laminar_fMRI_func_pRF.concatenateMeans, wf_laminar_fMRI_func_pRF.mcflirtBetweenSess, wf_laminar_fMRI_func_pRF.betweenMat, wf_laminar_fMRI_func_pRF.concatenateTransforms, wf_laminar_fMRI_func_pRF.copyTransforms, wf_laminar_fMRI_func_pRF.applyRealign, wf_laminar_fMRI_func_pRF.sliceTimingCorr, wf_laminar_fMRI_func_pRF.concatenateFunc, wf_laminar_fMRI_func_pRF.meanFunc, wf_laminar_fMRI_func_pRF.binarizeMeanFunc, wf_laminar_fMRI_func_pRF.datasourceManualEdits, wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask, wf_laminar_fMRI_func_pRF.makeOccLabel])
# 221202-14:02:51,220 nipype.workflow DEBUG:
# 	 [Node] subjects - setting input subject_id = sub-01
# 221202-14:02:51,221 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_sub-01
# 221202-14:02:51,223 nipype.workflow DEBUG:
# 	 Expanding the iterable node wf_laminar_fMRI_func_pRF.sessions...
# 221202-14:02:51,223 nipype.workflow DEBUG:
# 	 Excised the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join node in-edge.
# 221202-14:02:51,224 nipype.workflow DEBUG:
# 	 Excised the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join node in-edge.
# 221202-14:02:51,224 nipype.workflow DEBUG:
# 	 node: wf_laminar_fMRI_func_pRF.sessions iterables: {'sess_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x2aaae3fb9a60>, 'sess_nvol': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x2aaae3fb9620>, 'sess_nr': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x2aaae6a6e378>}
# 221202-14:02:51,225 nipype.workflow DEBUG:
# 	 ('subnodes:', [wf_laminar_fMRI_func_pRF.sessions, wf_laminar_fMRI_func_pRF.datasourceFunc.a0, wf_laminar_fMRI_func_pRF.discardDummies.a0, wf_laminar_fMRI_func_pRF.mcflirtWithinSess.a0, wf_laminar_fMRI_func_pRF.concatenateTransforms.a0, wf_laminar_fMRI_func_pRF.copyTransforms.a0, wf_laminar_fMRI_func_pRF.applyRealign.a0, wf_laminar_fMRI_func_pRF.sliceTimingCorr.a0, wf_laminar_fMRI_func_pRF.applyCoreg.a0, wf_laminar_fMRI_func_pRF.surfaceProject.a0, wf_laminar_fMRI_func_pRF.prfSink.a0, wf_laminar_fMRI_func_pRF.dataSink.a0, wf_laminar_fMRI_func_pRF.betweenMat.a0])
# 221202-14:02:51,232 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = task-bar_run-01
# 221202-14:02:51,248 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 0
# 221202-14:02:51,250 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 124
# 221202-14:02:51,252 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_task-bar_run-01_sess_nr_0_sess_nvol_124
# 221202-14:02:51,261 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = task-bar_run-02
# 221202-14:02:51,263 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 1
# 221202-14:02:51,265 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 124
# 221202-14:02:51,267 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_task-bar_run-02_sess_nr_1_sess_nvol_124
# 221202-14:02:51,275 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = task-pol_run-01
# 221202-14:02:51,277 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 2
# 221202-14:02:51,279 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 254
# 221202-14:02:51,281 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_task-pol_run-01_sess_nr_2_sess_nvol_254
# 221202-14:02:51,289 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = task-pol_run-02
# 221202-14:02:51,291 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 3
# 221202-14:02:51,293 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 254
# 221202-14:02:51,295 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_task-pol_run-02_sess_nr_3_sess_nvol_254
# 221202-14:02:51,303 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = task-ecc_run-01
# 221202-14:02:51,305 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 4
# 221202-14:02:51,307 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 131
# 221202-14:02:51,309 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_task-ecc_run-01_sess_nr_4_sess_nvol_131
# 221202-14:02:51,316 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = task-ecc_run-02
# 221202-14:02:51,320 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 5
# 221202-14:02:51,322 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 131
# 221202-14:02:51,324 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_task-ecc_run-02_sess_nr_5_sess_nvol_131
# 221202-14:02:51,332 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_id = rest_run-01
# 221202-14:02:51,334 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nr = 6
# 221202-14:02:51,336 nipype.workflow DEBUG:
# 	 [Node] sessions - setting input sess_nvol = 50
# 221202-14:02:51,338 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_sess_id_rest_run-01_sess_nr_6_sess_nvol_50
# 221202-14:02:51,341 nipype.workflow DEBUG:
# 	 The join node wf_laminar_fMRI_func_pRF.concatenateMeans input wf_laminar_fMRI_func_pRF.mcflirtWithinSess.a0 was expanded to 7 nodes.
# 221202-14:02:51,343 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ1'}.
# 221202-14:02:51,344 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ2'}.
# 221202-14:02:51,346 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ3'}.
# 221202-14:02:51,348 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ4'}.
# 221202-14:02:51,350 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ5'}.
# 221202-14:02:51,352 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ6'}.
# 221202-14:02:51,354 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateMeans join item fields {'in_files': 'in_filesJ7'}.
# 221202-14:02:51,356 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ1.
# 221202-14:02:51,358 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:51,359 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ2.
# 221202-14:02:51,361 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:51,362 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ3.
# 221202-14:02:51,363 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:51,363 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ4.
# 221202-14:02:51,364 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:51,364 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ5.
# 221202-14:02:51,371 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:51,371 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ6.
# 221202-14:02:51,372 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:51,372 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.mcflirtWithinSess -> wf_laminar_fMRI_func_pRF.concatenateMeans join field in_files as in_filesJ7.
# 221202-14:02:51,373 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateMeans subgraph to the expanded join point wf_laminar_fMRI_func_pRF.mcflirtWithinSess
# 221202-14:02:51,374 nipype.workflow DEBUG:
# 	 The join node wf_laminar_fMRI_func_pRF.concatenateFunc input wf_laminar_fMRI_func_pRF.sliceTimingCorr.a0 was expanded to 7 nodes.
# 221202-14:02:51,374 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ1'}.
# 221202-14:02:51,375 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ2'}.
# 221202-14:02:51,375 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ3'}.
# 221202-14:02:51,376 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ4'}.
# 221202-14:02:51,376 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ5'}.
# 221202-14:02:51,377 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ6'}.
# 221202-14:02:51,377 nipype.workflow DEBUG:
# 	 Added the wf_laminar_fMRI_func_pRF.concatenateFunc join item fields {'in_files': 'in_filesJ7'}.
# 221202-14:02:51,378 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ1.
# 221202-14:02:51,378 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:51,379 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ2.
# 221202-14:02:51,379 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:51,380 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ3.
# 221202-14:02:51,380 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:51,381 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ4.
# 221202-14:02:51,381 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:51,382 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ5.
# 221202-14:02:51,383 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:51,383 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ6.
# 221202-14:02:51,384 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:51,384 nipype.workflow DEBUG:
# 	 Qualified the wf_laminar_fMRI_func_pRF.sliceTimingCorr -> wf_laminar_fMRI_func_pRF.concatenateFunc join field in_files as in_filesJ7.
# 221202-14:02:51,385 nipype.workflow DEBUG:
# 	 Connected the join node wf_laminar_fMRI_func_pRF.concatenateFunc subgraph to the expanded join point wf_laminar_fMRI_func_pRF.sliceTimingCorr
# 221202-14:02:51,386 nipype.workflow DEBUG:
# 	 Expanding the iterable node wf_laminar_fMRI_func_pRF.hemi_depth...
# 221202-14:02:51,387 nipype.workflow DEBUG:
# 	 node: wf_laminar_fMRI_func_pRF.hemi_depth iterables: {'hemi': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x2aaae69cce18>, 'sampling_range': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x2aaae6afbd08>}
# 221202-14:02:51,387 nipype.workflow DEBUG:
# 	 ('subnodes:', [wf_laminar_fMRI_func_pRF.hemi_depth, wf_laminar_fMRI_func_pRF.surfaceProjectMeanFunc.a0, wf_laminar_fMRI_func_pRF.prfSink.a0.a0, wf_laminar_fMRI_func_pRF.prfSink.a0.a1, wf_laminar_fMRI_func_pRF.prfSink.a0.a2, wf_laminar_fMRI_func_pRF.prfSink.a0.a3, wf_laminar_fMRI_func_pRF.prfSink.a0.a4, wf_laminar_fMRI_func_pRF.prfSink.a0.a5, wf_laminar_fMRI_func_pRF.prfSink.a0.a6, wf_laminar_fMRI_func_pRF.surfaceProjectOccipitalMask.a0, wf_laminar_fMRI_func_pRF.makeOccLabel.a0, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a0, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a1, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a2, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a3, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a4, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a5, wf_laminar_fMRI_func_pRF.surfaceProject.a0.a6])
# 221202-14:02:51,402 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:51,420 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = -1.5
# 221202-14:02:51,421 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_-1.5
# 221202-14:02:51,439 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:51,440 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = -1.0
# 221202-14:02:51,441 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_-1.0
# 221202-14:02:51,459 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:51,460 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = -0.5
# 221202-14:02:51,460 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_-0.5
# 221202-14:02:51,474 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:51,475 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 0.0
# 221202-14:02:51,478 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_0.0
# 221202-14:02:51,490 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:51,492 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 0.5
# 221202-14:02:51,494 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_0.5
# 221202-14:02:51,506 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:51,508 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 1.0
# 221202-14:02:51,510 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_1.0
# 221202-14:02:51,522 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:51,523 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 1.5
# 221202-14:02:51,526 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_1.5
# 221202-14:02:51,537 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:51,540 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 2.0
# 221202-14:02:51,542 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_2.0
# 221202-14:02:51,553 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = lh
# 221202-14:02:51,555 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 2.5
# 221202-14:02:51,557 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_lh_sampling_range_2.5
# 221202-14:02:51,569 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:51,571 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = -1.5
# 221202-14:02:51,572 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_-1.5
# 221202-14:02:51,585 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:51,587 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = -1.0
# 221202-14:02:51,589 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_-1.0
# 221202-14:02:51,601 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:51,603 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = -0.5
# 221202-14:02:51,605 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_-0.5
# 221202-14:02:51,617 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:51,619 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 0.0
# 221202-14:02:51,621 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_0.0
# 221202-14:02:51,632 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:51,635 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 0.5
# 221202-14:02:51,637 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_0.5
# 221202-14:02:51,648 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:51,651 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 1.0
# 221202-14:02:51,653 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_1.0
# 221202-14:02:51,666 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:51,668 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 1.5
# 221202-14:02:51,670 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_1.5
# 221202-14:02:51,681 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:51,683 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 2.0
# 221202-14:02:51,686 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_2.0
# 221202-14:02:51,697 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input hemi = rh
# 221202-14:02:51,700 nipype.workflow DEBUG:
# 	 [Node] hemi_depth - setting input sampling_range = 2.5
# 221202-14:02:51,702 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_hemi_rh_sampling_range_2.5
# 221202-14:02:51,708 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 221202-14:02:51,713 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:51,716 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:51,718 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:51,719 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,721 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,723 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,725 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,727 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,729 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,731 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,733 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 2.5
# 221202-14:02:51,734 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 2.5
# 221202-14:02:51,736 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 2.5
# 221202-14:02:51,738 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,739 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,742 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,742 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,743 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,743 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,744 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,744 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:51,745 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:51,746 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:51,746 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:51,747 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,755 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,755 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,756 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,756 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,757 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,757 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,758 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 2.0
# 221202-14:02:51,758 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 2.0
# 221202-14:02:51,759 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 2.0
# 221202-14:02:51,759 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:51,760 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:51,760 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:51,761 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:51,761 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:51,762 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:51,762 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:51,762 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:51,763 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:51,763 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:51,764 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:51,764 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,765 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,765 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,766 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,766 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,767 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,767 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,768 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 1.5
# 221202-14:02:51,768 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 1.5
# 221202-14:02:51,769 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 1.5
# 221202-14:02:51,769 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:51,770 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:51,770 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:51,771 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:51,771 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:51,772 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:51,772 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.5
# 221202-14:02:51,773 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:51,773 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:51,774 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:51,774 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:51,777 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,777 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,778 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,778 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,787 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,787 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,788 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,788 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 1.0
# 221202-14:02:51,789 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 1.0
# 221202-14:02:51,789 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 1.0
# 221202-14:02:51,790 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:51,790 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:51,791 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:51,791 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:51,792 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:51,792 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:51,793 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 1.0
# 221202-14:02:51,793 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:51,794 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:51,794 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:51,795 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:51,796 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,796 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,797 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,797 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,798 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,807 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,808 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,809 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 0.5
# 221202-14:02:51,809 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 0.5
# 221202-14:02:51,809 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 0.5
# 221202-14:02:51,810 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:51,810 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:51,811 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:51,812 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:51,812 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:51,813 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:51,813 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.5
# 221202-14:02:51,814 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:51,814 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:51,815 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:51,815 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:51,816 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,816 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,817 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,817 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,818 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,819 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,819 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,820 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 0.0
# 221202-14:02:51,821 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 0.0
# 221202-14:02:51,821 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 0.0
# 221202-14:02:51,822 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:51,823 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:51,832 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:51,833 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:51,834 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:51,834 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:51,835 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 0.0
# 221202-14:02:51,835 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:51,836 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:51,836 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:51,837 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:51,837 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,838 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,838 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,839 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,840 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,840 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,841 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,841 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = -0.5
# 221202-14:02:51,842 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = -0.5
# 221202-14:02:51,842 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = -0.5
# 221202-14:02:51,843 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:51,843 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:51,844 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:51,844 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:51,845 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:51,846 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:51,855 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -0.5
# 221202-14:02:51,856 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:51,857 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:51,857 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:51,858 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:51,858 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,859 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,859 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,860 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,860 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,861 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,861 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,862 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = -1.0
# 221202-14:02:51,862 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = -1.0
# 221202-14:02:51,863 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = -1.0
# 221202-14:02:51,864 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:51,864 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:51,865 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:51,865 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:51,866 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:51,866 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:51,867 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.0
# 221202-14:02:51,867 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:51,868 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = rh
# 221202-14:02:51,869 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = rh
# 221202-14:02:51,872 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = rh
# 221202-14:02:51,873 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,873 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,874 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,874 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,875 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,883 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,884 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = rh
# 221202-14:02:51,884 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = -1.5
# 221202-14:02:51,885 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = -1.5
# 221202-14:02:51,885 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = -1.5
# 221202-14:02:51,886 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:51,886 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:51,887 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:51,887 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:51,888 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:51,888 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:51,889 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = -1.5
# 221202-14:02:51,889 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:51,890 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = lh
# 221202-14:02:51,891 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = lh
# 221202-14:02:51,891 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = lh
# 221202-14:02:51,892 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,892 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,893 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,893 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,894 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,895 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,904 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,905 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 2.5
# 221202-14:02:51,906 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 2.5
# 221202-14:02:51,906 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 2.5
# 221202-14:02:51,907 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,907 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,908 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,908 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,909 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,909 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,910 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.5
# 221202-14:02:51,910 nipype.workflow DEBUG:
# 	 Removed the identity node wf_laminar_fMRI_func_pRF.hemi_depth from the graph.
# 221202-14:02:51,911 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input hemi = lh
# 221202-14:02:51,911 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input hemi = lh
# 221202-14:02:51,912 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input hemi = lh
# 221202-14:02:51,912 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,913 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,913 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,914 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,914 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,915 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,915 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input hemi = lh
# 221202-14:02:51,916 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectMeanFunc - setting input sampling_range = 2.0
# 221202-14:02:51,916 nipype.workflow DEBUG:
# 	 [Node] surfaceProjectOccipitalMask - setting input sampling_range = 2.0
# 221202-14:02:51,918 nipype.workflow DEBUG:
# 	 [Node] makeOccLabel - setting input sampling_range = 2.0
# 221202-14:02:51,919 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:51,919 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:51,920 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:51,920 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# 221202-14:02:51,929 nipype.workflow DEBUG:
# 	 [Node] surfaceProject - setting input sampling_range = 2.0
# ...
# 221202-14:03:03,930 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "wf_laminar_fMRI_func_pRF.makeOccLabel".
# 221202-14:03:03,931 nipype.workflow DEBUG:
# 	 Only updating node hashes or skipping execution
# 221202-14:03:03,933 nipype.utils DEBUG:
# 	 Loading pkl: /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/_hemi_lh_sampling_range_-1.5/makeOccLabel/result_makeOccLabel.pklz
# 221202-14:03:03,957 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 221202-14:03:03,958 nipype.workflow INFO:
# 	 [Node] Cached "wf_laminar_fMRI_func_pRF.makeOccLabel" - collecting precomputed outputs
# 221202-14:03:03,958 nipype.workflow INFO:
# 	 [Node] "wf_laminar_fMRI_func_pRF.makeOccLabel" found cached.
# 221202-14:03:03,959 nipype.workflow INFO:
# 	 [Node] Setting-up "wf_laminar_fMRI_func_pRF.datasource" in "/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource".
# 221202-14:03:03,966 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/scratch/mayaaj90/project-00-7t-pipeline-dev'), ('drop_blank_outputs', False), ('field_template', [('T1', 'output/freesurfer_externalbrainmask/_subject_id_%s/T1.mgz'), ('UNI', 'output/anat/_subject_id_%s/UNI_corrected.nii'), ('fmap_magnitude1', 'raw/%s/fmap/magnitude1.nii'), ('fmap_magnitude2', 'raw/%s/fmap/magnitude2.nii'), ('fmap_phasediff', 'raw/%s/fmap/phasediff.nii')]), ('raise_on_empty', True), ('sort_filelist', False), ('subject_id', 'sub-01'), ('template', '*'), ('template_args', [('T1', [['subject_id']]), ('UNI', [['subject_id']]), ('fmap_magnitude1', [['subject_id']]), ('fmap_magnitude2', [['subject_id']]), ('fmap_phasediff', [['subject_id']])])], 540f8d1f5906d9ba823ec8535be104f2, /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource/_0x540f8d1f5906d9ba823ec8535be104f2.json, ['/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource/_0x540f8d1f5906d9ba823ec8535be104f2.json']
# 221202-14:03:03,966 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "wf_laminar_fMRI_func_pRF.datasource".
# 221202-14:03:03,967 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "wf_laminar_fMRI_func_pRF.datasource"
# 221202-14:03:03,973 nipype.utils DEBUG:
# 	 Removing contents of /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource
# 221202-14:03:03,988 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource/_report/report.rst"
# 221202-14:03:04,58 nipype.workflow INFO:
# 	 [Node] Executing "datasource" <nipype.interfaces.io.DataGrabber>
# 221202-14:03:04,63 nipype.workflow INFO:
# 	 [Node] Finished "datasource", elapsed time 0.002523s.
# 221202-14:03:04,70 nipype.workflow DEBUG:
# 	 Needed files: /scratch/mayaaj90/project-00-7t-pipeline-dev/output/anat/_subject_id_sub-01/UNI_corrected.nii;/scratch/mayaaj90/project-00-7t-pipeline-dev/output/anat/_subject_id_sub-01/UNI_corrected.mat;/scratch/mayaaj90/project-00-7t-pipeline-dev/output/freesurfer_externalbrainmask/_subject_id_sub-01/T1.mgz;/scratch/mayaaj90/project-00-7t-pipeline-dev/raw/sub-01/fmap/magnitude1.nii;/scratch/mayaaj90/project-00-7t-pipeline-dev/raw/sub-01/fmap/magnitude1.mat;/scratch/mayaaj90/project-00-7t-pipeline-dev/raw/sub-01/fmap/magnitude2.nii;/scratch/mayaaj90/project-00-7t-pipeline-dev/raw/sub-01/fmap/magnitude2.mat;/scratch/mayaaj90/project-00-7t-pipeline-dev/raw/sub-01/fmap/phasediff.nii;/scratch/mayaaj90/project-00-7t-pipeline-dev/raw/sub-01/fmap/phasediff.mat;/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource/_0x540f8d1f5906d9ba823ec8535be104f2_unfinished.json;/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource/_inputs.pklz;/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource/_node.pklz
# 221202-14:03:04,71 nipype.workflow DEBUG:
# 	 Needed dirs: /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource/_report
# 221202-14:03:04,71 nipype.workflow DEBUG:
# 	 Removing files:
# 221202-14:03:04,72 nipype.workflow DEBUG:
# 	 Saving results file: '/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource/result_datasource.pklz'
# 221202-14:03:04,85 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource/_report/report.rst"
# 221202-14:03:04,90 nipype.workflow INFO:
# 	 [Node] Setting-up "wf_laminar_fMRI_func_pRF.coreg" in "/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/coreg".
# 221202-14:03:04,93 nipype.workflow DEBUG:
# 	 [Node] Setting 4 connected inputs of node "coreg" from 3 previous nodes.
# 221202-14:03:04,95 nipype.utils DEBUG:
# 	 Loading pkl: /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource/result_datasource.pklz
# 221202-14:03:04,100 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 221202-14:03:04,101 nipype.workflow DEBUG:
# 	 output: UNI
# 221202-14:03:04,101 nipype.workflow DEBUG:
# 	 [Node] coreg - setting input fixed_image = /scratch/mayaaj90/project-00-7t-pipeline-dev/output/anat/_subject_id_sub-01/UNI_corrected.nii
# 221202-14:03:04,102 nipype.utils DEBUG:
# 	 Loading pkl: /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasourceManualEdits/result_datasourceManualEdits.pklz
# 221202-14:03:04,109 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 221202-14:03:04,109 nipype.workflow DEBUG:
# 	 output: coreg_itksnap_func2struct_txt
# 221202-14:03:04,110 nipype.workflow DEBUG:
# 	 [Node] coreg - setting input initial_moving_transform = /scratch/mayaaj90/project-00-7t-pipeline-dev/manualcorr/func/_subject_id_sub-01/coreg_itksnap_func2struct.txt
# 221202-14:03:04,111 nipype.workflow DEBUG:
# 	 output: manual_midoccmask
# 221202-14:03:04,111 nipype.workflow DEBUG:
# 	 [Node] coreg - setting input fixed_image_masks = /scratch/mayaaj90/project-00-7t-pipeline-dev/manualcorr/func/_subject_id_sub-01/midoccMask.nii
# 221202-14:03:04,112 nipype.utils DEBUG:
# 	 Loading pkl: /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/meanFunc/result_meanFunc.pklz
# 221202-14:03:04,121 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 221202-14:03:04,122 nipype.workflow DEBUG:
# 	 output: mean_img
# 221202-14:03:04,123 nipype.workflow DEBUG:
# 	 [Node] coreg - setting input moving_image = /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/meanFunc/merged_func_mcf.nii_mean_reg.nii
# 221202-14:03:04,131 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('collapse_output_transforms', True), ('convergence_threshold', ['0.0000010000', '0.0000010000', '0.0000010000']), ('convergence_window_size', [10, 10, 10]), ('dimension', 3), ('fixed_image', [('/scratch/mayaaj90/project-00-7t-pipeline-dev/output/anat/_subject_id_sub-01/UNI_corrected.nii', '4a29943c72cca86b8016b959b283f52c')]), ('fixed_image_masks', [('/scratch/mayaaj90/project-00-7t-pipeline-dev/manualcorr/func/_subject_id_sub-01/midoccMask.nii', '061e28ecfdb3dd69879a18080ed8bbc3')]), ('float', True), ('initial_moving_transform', [('/scratch/mayaaj90/project-00-7t-pipeline-dev/manualcorr/func/_subject_id_sub-01/coreg_itksnap_func2struct.txt', 'cda91994f6734aa1e1bc3ec33dadad92')]), ('initialize_transforms_per_stage', False), ('interpolation', 'Linear'), ('metric', ['MI', 'MI', 'CC']), ('metric_weight', ['1.0000000000', '1.0000000000', '1.0000000000']), ('metric_weight_item_trait', '1.0000000000'), ('moving_image', [('/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/meanFunc/merged_func_mcf.nii_mean_reg.nii', 'a9563dad0b758b60d866885d2ab415b8')]), ('number_of_iterations', [[1000, 500, 250, 100], [1000, 500, 250, 100], [100, 70, 50, 20]]), ('output_inverse_warped_image', 'registered_InverseWarped.nii.gz'), ('output_transform_prefix', 'registered_'), ('output_warped_image', 'registered_Warped.nii.gz'), ('radius_bins_item_trait', 5), ('radius_or_number_of_bins', [32, 32, 4]), ('sampling_percentage', ['0.2500000000', '0.2500000000', None]), ('sampling_strategy', ['Regular', 'Regular', 'None']), ('shrink_factors', [[8, 4, 2, 1], [8, 4, 2, 1], [8, 4, 2, 1]]), ('smoothing_sigmas', [['3.0000000000', '2.0000000000', '1.0000000000', '0.0000000000'], ['3.0000000000', '2.0000000000', '1.0000000000', '0.0000000000'], ['3.0000000000', '2.0000000000', '1.0000000000', '0.0000000000']]), ('transform_parameters', [('0.1000000000',), ('0.1000000000',), ('0.1000000000', '3.0000000000', '0.0000000000')]), ('transforms', ['Rigid', 'Affine', 'SyN']), ('use_histogram_matching', False), ('winsorize_lower_quantile', '0.0050000000'), ('winsorize_upper_quantile', '0.9950000000'), ('write_composite_transform', False)], 49e96ea88fb942ed74b4c005f9a75eef, /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/coreg/_0x49e96ea88fb942ed74b4c005f9a75eef.json, ['/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/coreg/_0x49e96ea88fb942ed74b4c005f9a75eef.json']
# 221202-14:03:04,132 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "wf_laminar_fMRI_func_pRF.coreg".
# 221202-14:03:04,132 nipype.workflow DEBUG:
# 	 Only updating node hashes or skipping execution
# 221202-14:03:04,136 nipype.utils DEBUG:
# 	 Loading pkl: /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/coreg/result_coreg.pklz
# 221202-14:03:04,160 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 221202-14:03:04,161 nipype.workflow INFO:
# 	 [Node] Cached "wf_laminar_fMRI_func_pRF.coreg" - collecting precomputed outputs
# 221202-14:03:04,162 nipype.workflow INFO:
# 	 [Node] "wf_laminar_fMRI_func_pRF.coreg" found cached.
# 221202-14:03:04,163 nipype.workflow INFO:
# 	 [Node] Setting-up "wf_laminar_fMRI_func_pRF.applyCoreg" in "/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/_sess_id_rest_run-01_sess_nr_6_sess_nvol_50/applyCoreg".
# 221202-14:03:04,169 nipype.workflow DEBUG:
# 	 [Node] Setting 3 connected inputs of node "applyCoreg" from 3 previous nodes.
# 221202-14:03:04,170 nipype.utils DEBUG:
# 	 Loading pkl: /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/_sess_id_rest_run-01_sess_nr_6_sess_nvol_50/sliceTimingCorr/result_sliceTimingCorr.pklz
# 221202-14:03:04,175 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 221202-14:03:04,176 nipype.workflow DEBUG:
# 	 output: timecorrected_files
# 221202-14:03:04,177 nipype.workflow DEBUG:
# 	 [Node] applyCoreg - setting input input_image = /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/_sess_id_rest_run-01_sess_nr_6_sess_nvol_50/sliceTimingCorr/arest_run-01_roi_warp4D.nii
# 221202-14:03:04,177 nipype.utils DEBUG:
# 	 Loading pkl: /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/datasource/result_datasource.pklz
# 221202-14:03:04,184 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 221202-14:03:04,185 nipype.workflow DEBUG:
# 	 output: UNI
# 221202-14:03:04,186 nipype.workflow DEBUG:
# 	 [Node] applyCoreg - setting input reference_image = /scratch/mayaaj90/project-00-7t-pipeline-dev/output/anat/_subject_id_sub-01/UNI_corrected.nii
# 221202-14:03:04,186 nipype.utils DEBUG:
# 	 Loading pkl: /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/coreg/result_coreg.pklz
# 221202-14:03:04,191 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 221202-14:03:04,193 nipype.workflow DEBUG:
# 	 output: forward_transforms
# 221202-14:03:04,194 nipype.workflow DEBUG:
# 	 [Node] applyCoreg - setting input transforms = ['/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/coreg/registered_0GenericAffine.mat', '/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/coreg/registered_1Warp.nii.gz']
# 221202-14:03:04,202 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('default_value', '0.0000000000'), ('float', False), ('input_image', ('/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/_sess_id_rest_run-01_sess_nr_6_sess_nvol_50/sliceTimingCorr/arest_run-01_roi_warp4D.nii', '515885d04cae9e4a4f0a620ae75bd7b6')), ('input_image_type', 3), ('interpolation', 'BSpline'), ('interpolation_parameters', (5,)), ('out_postfix', '_trans'), ('reference_image', ('/scratch/mayaaj90/project-00-7t-pipeline-dev/output/anat/_subject_id_sub-01/UNI_corrected.nii', '4a29943c72cca86b8016b959b283f52c')), ('transforms', [('/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/coreg/registered_0GenericAffine.mat', '490f64f270488ab76fedacf9a4c20d08'), ('/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/coreg/registered_1Warp.nii.gz', '522aeae5998146294b37a3b70bccc1fa')])], 1940b291efdea9f430b6ee98206a4ca8, /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/_sess_id_rest_run-01_sess_nr_6_sess_nvol_50/applyCoreg/_0x1940b291efdea9f430b6ee98206a4ca8.json, []
# 221202-14:03:04,203 nipype.workflow DEBUG:
# 	 [Node] No hashfiles found in "/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/_sess_id_rest_run-01_sess_nr_6_sess_nvol_50/applyCoreg".
# 221202-14:03:04,204 nipype.utils DEBUG:
# 	 Removing contents of /scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/_sess_id_rest_run-01_sess_nr_6_sess_nvol_50/applyCoreg
# 221202-14:03:04,259 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/_sess_id_rest_run-01_sess_nr_6_sess_nvol_50/applyCoreg/_report/report.rst"
# 221202-14:03:04,339 nipype.workflow INFO:
# 	 [Node] Executing "applyCoreg" <nipype.interfaces.ants.resampling.ApplyTransforms>
# 221202-14:03:04,342 nipype.interface DEBUG:
# 	 default_value_0.0
# 221202-14:03:04,342 nipype.interface DEBUG:
# 	 float_False
# 221202-14:03:04,343 nipype.interface DEBUG:
# 	 input_image_/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/_sess_id_rest_run-01_sess_nr_6_sess_nvol_50/sliceTimingCorr/arest_run-01_roi_warp4D.nii
# 221202-14:03:04,343 nipype.interface DEBUG:
# 	 input_image_type_3
# 221202-14:03:04,344 nipype.interface DEBUG:
# 	 reference_image_/scratch/mayaaj90/project-00-7t-pipeline-dev/output/anat/_subject_id_sub-01/UNI_corrected.nii
# 221202-14:03:04,345 nipype.interface DEBUG:
# 	 default_value_0.0
# 221202-14:03:04,345 nipype.interface DEBUG:
# 	 float_False
# 221202-14:03:04,346 nipype.interface DEBUG:
# 	 input_image_/scratch/mayaaj90/project-00-7t-pipeline-dev/derivatives/wf_laminar_fMRI_func_pRF/_subject_id_sub-01/_sess_id_rest_run-01_sess_nr_6_sess_nvol_50/sliceTimingCorr/arest_run-01_roi_warp4D.nii
# 221202-14:03:04,346 nipype.interface DEBUG:
# 	 input_image_type_3
# 221202-14:03:04,347 nipype.interface DEBUG:
# 	 reference_image_/scratch/mayaaj90/project-00-7t-pipeline-dev/output/anat/_subject_id_sub-01/UNI_corrected.nii
